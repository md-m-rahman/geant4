# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.special import spherical_jn
from scipy.integrate import cumulative_trapezoid

csv_file = "/root/geant4/fac/Cs_all_wavefunctions.csv"
df = pd.read_csv(csv_file)
df = df.dropna(subset=["r", "P", "Q"])

p = np.arange(0.0, 300.0 + 0.05, 0.05)
Qgrid = np.arange(0.0, 100.0 + 0.05, 0.05)

print(df["Orbital"].unique())


def get_orbital(df, name, print_values=True):
    d = df[df["Orbital"] == name].copy()
    d = d.sort_values("r")

    r_raw = d["r"].to_numpy()
    P_raw = d["P"].to_numpy()
    Q_raw = d["Q"].to_numpy()

    if print_values:
        print("\n======================")
        print(name)
        print("======================")
        print(d[["r", "P", "Q"]].head(8))
        print(d[["r", "P", "Q"]].tail(8))

    raw_norm = np.trapezoid(P_raw**2 + Q_raw**2, r_raw)
    print(name, "raw radial norm ∫(P²+Q²)dr =", raw_norm)

    # normalize raw FAC P,Q
    P_raw = P_raw / np.sqrt(raw_norm)
    Q_raw = Q_raw / np.sqrt(raw_norm)

    # interpolate to finer r grid
    r = np.linspace(r_raw.min(), r_raw.max(), 5000)
    P = np.interp(r, r_raw, P_raw)
    Qs = np.interp(r, r_raw, Q_raw)

    fine_norm = np.trapezoid(P**2 + Qs**2, r)
    P = P / np.sqrt(fine_norm)
    Qs = Qs / np.sqrt(fine_norm)

    print(name, "fine radial norm after interpolation =", np.trapezoid(P**2 + Qs**2, r))

    return r, P, Qs
   # return r_raw, P_raw, Q_raw

def chi_transform(p_grid, r, radial, l):
    chi = []

    for pp in p_grid:
        jl = spherical_jn(l, pp*r)

        # FAC P = rG, Q = rF
        # chi = sqrt(2/pi) int P(r) j_l(pr) r dr
        val = np.sqrt(2/np.pi) * np.trapezoid(radial * jl * r, r)

        chi.append(val)

    return np.array(chi)


def calculate_J(p_grid, chiG, chiF, Qgrid):
    integrand = (chiG**2 + chiF**2) * p_grid

    rev = cumulative_trapezoid(
        integrand[::-1],
        p_grid[::-1],
        initial=0
    )

    J_p = -0.5 * rev[::-1]
    J_Q = np.interp(Qgrid, p_grid, J_p)

    return J_Q


def one_orbital_J(df, name, l_large, l_small):
    r, P, Qs = get_orbital(df, name)

    chiG = chi_transform(p, r, P, l_large)
    chiF = chi_transform(p, r, Qs, l_small)

    I = (chiG**2 + chiF**2) * p**2
    print(name, "momentum norm ∫I(p)dp =", np.trapezoid(I, p))

    J = calculate_J(p, chiG, chiF, Qgrid)
    print(name, "Compton check 2∫J(Q)dQ =", 2*np.trapezoid(J, Qgrid))

    return J


# =====================================================
# Relativistic orbitals
# large component l = orbital l
# small component l' is decided by j
# =====================================================

J_1s12 = one_orbital_J(df, "Cs_1s12", 0, 1)

J_2s12 = one_orbital_J(df, "Cs_2s12", 0, 1)
J_2p12 = one_orbital_J(df, "Cs_2p12", 1, 0)
J_2p32 = one_orbital_J(df, "Cs_2p32", 1, 2)

J_3s12 = one_orbital_J(df, "Cs_3s12", 0, 1)
J_3p12 = one_orbital_J(df, "Cs_3p12", 1, 0)
J_3p32 = one_orbital_J(df, "Cs_3p32", 1, 2)

J_3d32 = one_orbital_J(df, "Cs_3d32", 2, 1)
J_3d52 = one_orbital_J(df, "Cs_3d52", 2, 3)

J_4s12 = one_orbital_J(df, "Cs_4s12", 0, 1)
J_4p12 = one_orbital_J(df, "Cs_4p12", 1, 0)
J_4p32 = one_orbital_J(df, "Cs_4p32", 1, 2)
J_4d32 = one_orbital_J(df, "Cs_4d32", 2, 1)
J_4d52 = one_orbital_J(df, "Cs_4d52", 2, 3)

J_5s12 = one_orbital_J(df, "Cs_5s12", 0, 1)
J_5p12 = one_orbital_J(df, "Cs_5p12", 1, 0)
J_5p32 = one_orbital_J(df, "Cs_5p32", 1, 2)

J_6s12 = one_orbital_J(df, "Cs_6s12", 0, 1)

J_total_Cs_rel = (
    2*J_1s12
    + 2*J_2s12
    + 2*J_2p12 + 4*J_2p32
    + 2*J_3s12
    + 2*J_3p12 + 4*J_3p32
    + 4*J_3d32 + 6*J_3d52
    + 2*J_4s12
    + 2*J_4p12 + 4*J_4p32
    + 4*J_4d32 + 6*J_4d52
    + 2*J_5s12
    + 2*J_5p12 + 4*J_5p32
    + 1*J_6s12
    )

print("\nTotal Cs check 2∫Jtotal dQ =", 2*np.trapezoid(J_total_Cs_rel, Qgrid))
print("Expected close to 55")


table = pd.DataFrame({
    "Q": Qgrid,
    "J_1s1/2(2)": J_1s12,
    "J_2s1/2(2)": J_2s12,
    "J_2p1/2(2)": J_2p12,
    "J_2p3/2(4)": J_2p32,
    "J_3s1/2(2)": J_3s12,
    "J_3p1/2(2)": J_3p12,
    "J_3p3/2(4)": J_3p32,
    "J_3d3/2(4)": J_3d32,
    "J_3d5/2(6)": J_3d52,
    "J_4s1/2(2)": J_4s12,
    "J_4p1/2(2)": J_4p12,
    "J_4p3/2(4)": J_4p32,
    "J_4d3/2(4)": J_4d32,
    "J_4d5/2(4)": J_4d52,
    "J_5s1/2(2)": J_5s12,
    "J_5p1/2(2)": J_5p12,
    "J_5p3/2(2)": J_5p32,
    "J_6s1/2(1)": J_6s12,
    "J_total_Cs_relativistic": J_total_Cs_rel
})

table.to_csv("Cs_relativistic_Compton_profile.csv", index=False)
print(table)


plt.figure(figsize=(8,6))
plt.plot(Qgrid, 2*J_1s12, label="1s(2)")
plt.plot(Qgrid, 2*J_2s12, label="2s(2)")
plt.plot(Qgrid, 2*J_2p12 + 4*J_2p32, label="2p(6)")
plt.plot(Qgrid, 2*J_3s12, label="3s(2)")
plt.plot(Qgrid, 2*J_3p12 + 4*J_3p32, label="3p(6)")
plt.plot(Qgrid, 4*J_3d32 + 6*J_3d52, label="3d(10)")
plt.plot(Qgrid, 2*J_4s12, label="4s(2)")
plt.plot(Qgrid, 2*J_4p12 + 4*J_4p32, label="4p(6)")
plt.plot(Qgrid, 4*J_4d32 + 6*J_4d52, label="4d(10)")
plt.plot(Qgrid, 2*J_5s12, label="5s(2)")
plt.plot(Qgrid, 2*J_5p12 + 4*J_5p32, label="5p(3)")
plt.plot(Qgrid, 1*J_6s12, label="6s(1)")
plt.plot(Qgrid, J_total_Cs_rel, label="Cs total relativistic", linewidth=2)

plt.xlabel("Q (a.u.)")
plt.ylabel("J(Q)")
plt.title("Relativistic Cs Compton Profile")
plt.yscale("log")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# ['Cs_1s12' 'Cs_2p12' 'Cs_2p32' 'Cs_2s12' 'Cs_3d32' 'Cs_3d52' 'Cs_3p12'
#  'Cs_3p32' 'Cs_3s12' 'Cs_4d32' 'Cs_4d52' 'Cs_4p12' 'Cs_4p32' 'Cs_4s12'
#  'Cs_5p12' 'Cs_5p32' 'Cs_5s12' 'Cs_6s12']
#
# ======================
# Cs_1s12
# ======================
#               r         P             Q
# 0  1.818182e-08  0.000023 -7.431533e-10
# 1  1.993850e-08  0.000025 -8.936121e-10
# 2  2.186492e-08  0.000028 -1.074553e-09
# 3  2.397741e-08  0.000030 -1.292144e-09
# 4  2.629401e-08  0.000033 -1.553814e-09
# 5  2.883443e-08  0.000037 -1.868491e-09
# 6  3.162023e-08  0.000040 -2.246904e-09
# 7  3.467518e-08  0.000044 -2.701968e-09
#             r             P             Q
# 196  0.367426  8.044731e-07 -1.554623e-07
# 197  0.388709  2.795524e-07 -5.364104e-08
# 198  0.410971  9.233531e-08 -1.756714e-08
# 199  0.434242  2.894293e-08 -5.450082e-09
# 200  0.458551  8.595867e-09 -1.598516e-09
# 201  0.483928  2.414872e-09 -4.422709e-10
# 202  0.510402  6.406490e-10 -1.672090e-10
# 203  0.538003  1.602170e-10  1.048795e-10
# Cs_1s12 raw radial norm ∫(P²+Q²)dr = 1.0008260174110262
# Cs_1s12 fine radial norm after interpolation = 1.0000000000000002
# Cs_1s12 momentum norm ∫I(p)dp = 0.9979394864394391
# Cs_1s12 Compton check 2∫J(Q)dQ = 0.9814910197413934
#
# ======================
# Cs_2s12
# ======================
#                 r         P             Q
# 654  1.818182e-08  0.000008 -2.599546e-10
# 655  1.993850e-08  0.000009 -3.125851e-10
# 656  2.186492e-08  0.000010 -3.758780e-10
# 657  2.397741e-08  0.000011 -4.519915e-10
# 658  2.629401e-08  0.000012 -5.435237e-10
# 659  2.883443e-08  0.000013 -6.535976e-10
# 660  3.162023e-08  0.000014 -7.859661e-10
# 661  3.467518e-08  0.000015 -9.451475e-10
#             r             P             Q
# 870  1.012789 -2.530407e-07  1.920557e-08
# 871  1.059251 -9.974221e-08  7.543675e-09
# 872  1.107276 -3.805056e-08  2.866343e-09
# 873  1.156891 -1.404111e-08  1.052936e-09
# 874  1.208124 -5.009140e-09  3.737132e-10
# 875  1.261001 -1.726665e-09  1.280750e-10
# 876  1.315551 -5.747726e-10  4.997289e-11
# 877  1.371799 -1.846647e-10 -5.740625e-12
# Cs_2s12 raw radial norm ∫(P²+Q²)dr = 1.000497349267274
# Cs_2s12 fine radial norm after interpolation = 1.0000000000000002
# Cs_2s12 momentum norm ∫I(p)dp = 0.9997300055972518
# Cs_2s12 Compton check 2∫J(Q)dQ = 0.9971297715811386
#
# ======================
# Cs_2p12
# ======================
#                 r             P         Q
# 204  1.818182e-08  4.747274e-11  0.000001
# 205  1.993850e-08  5.706045e-11  0.000002
# 206  2.186492e-08  6.859283e-11  0.000002
# 207  2.397741e-08  8.246350e-11  0.000002
# 208  2.629401e-08  9.914591e-11  0.000002
# 209  2.883443e-08  1.192094e-10  0.000002
# 210  3.162023e-08  1.433386e-10  0.000002
# 211  3.467518e-08  1.723568e-10  0.000003
#             r             P             Q
# 420  1.012789  2.658165e-07 -1.773203e-08
# 421  1.059251  1.075380e-07 -7.180705e-09
# 422  1.107276  4.214930e-08 -2.815309e-09
# 423  1.156891  1.599701e-08 -1.068053e-09
# 424  1.208124  5.875951e-09 -3.918489e-10
# 425  1.261001  2.087747e-09 -1.389473e-10
# 426  1.315551  7.171430e-10 -5.577862e-11
# 427  1.371799  2.380280e-10  4.963113e-12
# Cs_2p12 raw radial norm ∫(P²+Q²)dr = 1.0005353909331027
# Cs_2p12 fine radial norm after interpolation = 0.9999999999999999
# Cs_2p12 momentum norm ∫I(p)dp = 0.9999875764500468
# Cs_2p12 Compton check 2∫J(Q)dQ = 0.9997216734623925
#
# ======================
# Cs_2p32
# ======================
#                 r             P             Q
# 428  1.818182e-08  1.725479e-12 -3.347672e-17
# 429  1.993850e-08  2.073961e-12 -4.413748e-17
# 430  2.186492e-08  2.493126e-12 -5.818856e-17
# 431  2.397741e-08  2.997279e-12 -7.671166e-17
# 432  2.629401e-08  3.603631e-12 -1.011337e-16
# 433  2.883443e-08  4.332875e-12 -1.333359e-16
# 434  3.162023e-08  5.209893e-12 -1.757981e-16
# 435  3.467518e-08  6.264612e-12 -2.317920e-16
#             r             P             Q
# 646  1.107276  8.924839e-08 -6.652471e-09
# 647  1.156891  3.502632e-08 -2.596600e-09
# 648  1.208124  1.331847e-08 -9.816382e-10
# 649  1.261001  4.904119e-09 -3.592338e-10
# 650  1.315551  1.747809e-09 -1.271841e-10
# 651  1.371799  6.026027e-10 -4.353747e-11
# 652  1.429772  2.008855e-10 -1.692313e-11
# 653  1.489497  6.471731e-11  1.781125e-12
# Cs_2p32 raw radial norm ∫(P²+Q²)dr = 1.000519976134911
# Cs_2p32 fine radial norm after interpolation = 0.9999999999999999
# Cs_2p32 momentum norm ∫I(p)dp = 0.999998575015849
# Cs_2p32 Compton check 2∫J(Q)dQ = 0.9998968337546419
#
# ======================
# Cs_3s12
# ======================
#                  r         P             Q
# 1878  1.818182e-08  0.000004 -1.170631e-10
# 1879  1.993850e-08  0.000004 -1.407637e-10
# 1880  2.186492e-08  0.000004 -1.692659e-10
# 1881  2.397741e-08  0.000005 -2.035414e-10
# 1882  2.629401e-08  0.000005 -2.447603e-10
# 1883  2.883443e-08  0.000006 -2.943289e-10
# 1884  3.162023e-08  0.000006 -3.539373e-10
# 1885  3.467518e-08  0.000007 -4.256201e-10
#              r             P             Q
# 2116  2.436628  3.238577e-08 -1.127887e-09
# 2117  2.523447  1.455096e-08 -5.057792e-10
# 2118  2.612374  6.408279e-09 -2.222898e-10
# 2119  2.703429  2.765847e-09 -9.573228e-11
# 2120  2.796634  1.169710e-09 -4.039233e-11
# 2121  2.892009  4.846390e-10 -1.669418e-11
# 2122  2.989575  1.966863e-10 -7.242597e-12
# 2123  3.089352  7.817554e-11 -1.472427e-12
# Cs_3s12 raw radial norm ∫(P²+Q²)dr = 1.0002937948342225
# Cs_3s12 fine radial norm after interpolation = 1.0000000000000002
# Cs_3s12 momentum norm ∫I(p)dp = 0.9999442437099503
# Cs_3s12 Compton check 2∫J(Q)dQ = 0.9993944648076887
#
# ======================
# Cs_3p12
# ======================
#                  r             P             Q
# 1382  1.818182e-08  2.233855e-11  6.568955e-07
# 1383  1.993850e-08  2.685010e-11  7.203518e-07
# 1384  2.186492e-08  3.227672e-11  7.899540e-07
# 1385  2.397741e-08  3.880364e-11  8.662784e-07
# 1386  2.629401e-08  4.665364e-11  9.499695e-07
# 1387  2.883443e-08  5.609463e-11  1.041752e-06
# 1388  3.162023e-08  6.744873e-11  1.142401e-06
# 1389  3.467518e-08  8.110340e-11  1.252772e-06
#              r             P             Q
# 1622  2.612374 -1.787736e-08  5.361821e-10
# 1623  2.703429 -8.112366e-09  2.435433e-10
# 1624  2.796634 -3.611663e-09  1.085048e-10
# 1625  2.892009 -1.577301e-09  4.740943e-11
# 1626  2.989575 -6.756180e-10  2.031218e-11
# 1627  3.089352 -2.837908e-10  8.532082e-12
# 1628  3.191360 -1.168790e-10  3.767988e-12
# 1629  3.295617 -4.718960e-11  7.842292e-13
# Cs_3p12 raw radial norm ∫(P²+Q²)dr = 1.0003026534671227
# Cs_3p12 fine radial norm after interpolation = 1.0000000000000002
# Cs_3p12 momentum norm ∫I(p)dp = 0.9999969674500683
# Cs_3p12 Compton check 2∫J(Q)dQ = 0.999935133345038
#
# ======================
# Cs_3p32
# ======================
#                  r             P             Q
# 1630  1.818182e-08  8.206460e-13 -1.591234e-17
# 1631  1.993850e-08  9.863856e-13 -2.097967e-17
# 1632  2.186492e-08  1.185742e-12 -2.765850e-17
# 1633  2.397741e-08  1.425520e-12 -3.646301e-17
# 1634  2.629401e-08  1.713904e-12 -4.807143e-17
# 1635  2.883443e-08  2.060736e-12 -6.337796e-17
# 1636  3.162023e-08  2.477849e-12 -8.356132e-17
# 1637  3.467518e-08  2.979479e-12 -1.101766e-16
#              r             P             Q
# 1870  2.612374 -3.742304e-08  1.241254e-09
# 1871  2.703429 -1.744084e-08  5.766319e-10
# 1872  2.796634 -7.979638e-09  2.629730e-10
# 1873  2.892009 -3.583624e-09  1.177150e-10
# 1874  2.989575 -1.579502e-09  5.171222e-11
# 1875  3.089352 -6.831418e-10  2.229085e-11
# 1876  3.191360 -2.898871e-10  9.936567e-12
# 1877  3.295617 -1.206724e-10  2.652257e-12
# Cs_3p32 raw radial norm ∫(P²+Q²)dr = 1.0002947405297764
# Cs_3p32 fine radial norm after interpolation = 0.9999999999999998
# Cs_3p32 momentum norm ∫I(p)dp = 0.9999994210498471
# Cs_3p32 Compton check 2∫J(Q)dQ = 0.9999751625718937
#
# ======================
# Cs_3d32
# ======================
#                 r             P             Q
# 878  1.818182e-08  9.218892e-19  4.496253e-14
# 879  1.993850e-08  1.212625e-18  5.406796e-14
# 880  2.186492e-08  1.596561e-18  6.502155e-14
# 881  2.397741e-08  2.103314e-18  7.819298e-14
# 882  2.629401e-08  2.771956e-18  9.403177e-14
# 883  2.883443e-08  3.654029e-18  1.130795e-13
# 884  3.162023e-08  4.817503e-18  1.359854e-13
# 885  3.467518e-08  6.352030e-18  1.635309e-13
#              r             P             Q
# 1122  2.989575  1.686412e-08 -4.042673e-10
# 1123  3.089352  8.151912e-09 -1.959398e-10
# 1124  3.191360  3.876514e-09 -9.340159e-11
# 1125  3.295617  1.813233e-09 -4.378365e-11
# 1126  3.402143  8.341412e-10 -2.018100e-11
# 1127  3.510958  3.773491e-10 -9.145195e-12
# 1128  3.622080  1.678449e-10 -4.280925e-12
# 1129  3.735526  7.339684e-11 -1.272722e-12
# Cs_3d32 raw radial norm ∫(P²+Q²)dr = 1.0003085145714976
# Cs_3d32 fine radial norm after interpolation = 1.0
# Cs_3d32 momentum norm ∫I(p)dp = 0.9999999322568422
# Cs_3d32 Compton check 2∫J(Q)dQ = 0.9999995619677855
#
# ======================
# Cs_3d52
# ======================
#                  r             P             Q
# 1130  1.818182e-08  4.025803e-20 -5.587942e-25
# 1131  1.993850e-08  5.295419e-20 -8.074618e-25
# 1132  2.186492e-08  6.972031e-20 -1.166054e-24
# 1133  2.397741e-08  9.184972e-20 -1.683975e-24
# 1134  2.629401e-08  1.210488e-19 -2.432590e-24
# 1135  2.883443e-08  1.595681e-19 -3.515010e-24
# 1136  3.162023e-08  2.103760e-19 -5.080266e-24
# 1137  3.467518e-08  2.773874e-19 -7.343894e-24
#              r             P             Q
# 1374  2.989575  2.087503e-08 -6.227066e-10
# 1375  3.089352  1.016502e-08 -3.018846e-10
# 1376  3.191360  4.870203e-09 -1.440076e-10
# 1377  3.295617  2.295558e-09 -6.758636e-11
# 1378  3.402143  1.064331e-09 -3.120347e-11
# 1379  3.510958  4.853519e-10 -1.416962e-11
# 1380  3.622080  2.176569e-10 -6.569511e-12
# 1381  3.735526  9.597715e-11 -2.187633e-12
# Cs_3d52 raw radial norm ∫(P²+Q²)dr = 1.0003056816420144
# Cs_3d52 fine radial norm after interpolation = 0.9999999999999998
# Cs_3d52 momentum norm ∫I(p)dp = 0.9999999330758531
# Cs_3d52 Compton check 2∫J(Q)dQ = 0.9999997118938262
#
# ======================
# Cs_4s12
# ======================
#                  r         P             Q
# 3272  1.818182e-08  0.000002 -5.541003e-11
# 3273  1.993850e-08  0.000002 -6.662835e-11
# 3274  2.186492e-08  0.000002 -8.011941e-11
# 3275  2.397741e-08  0.000002 -9.634321e-11
# 3276  2.629401e-08  0.000002 -1.158535e-10
# 3277  2.883443e-08  0.000003 -1.393161e-10
# 3278  3.162023e-08  0.000003 -1.675308e-10
# 3279  3.467518e-08  0.000003 -2.014607e-10
#              r             P             Q
# 3538  5.727888 -9.834413e-09  1.494483e-10
# 3539  5.880814 -5.331455e-09  8.093207e-11
# 3540  6.036337 -2.859878e-09  4.336691e-11
# 3541  6.194471 -1.517854e-09  2.299216e-11
# 3542  6.355230 -7.970197e-10  1.206035e-11
# 3543  6.518627 -4.140394e-10  6.258567e-12
# 3544  6.684675 -2.127769e-10  3.270748e-12
# 3545  6.853387 -1.081670e-10  1.492738e-12
# Cs_4s12 raw radial norm ∫(P²+Q²)dr = 1.0001622902869443
# Cs_4s12 fine radial norm after interpolation = 1.0
# Cs_4s12 momentum norm ∫I(p)dp = 0.9999874119952189
# Cs_4s12 Compton check 2∫J(Q)dQ = 0.9998630093545289
#
# ======================
# Cs_4p12
# ======================
#                  r             P             Q
# 2714  1.818182e-08  1.030385e-11  3.029862e-07
# 2715  1.993850e-08  1.238484e-11  3.322548e-07
# 2716  2.186492e-08  1.488792e-11  3.643581e-07
# 2717  2.397741e-08  1.789851e-11  3.995619e-07
# 2718  2.629401e-08  2.151939e-11  4.381635e-07
# 2719  2.883443e-08  2.587413e-11  4.804973e-07
# 2720  3.162023e-08  3.111131e-11  5.269205e-07
# 2721  3.467518e-08  3.740965e-11  5.778280e-07
#              r             P             Q
# 2984  6.355230  1.003750e-08 -1.231874e-10
# 2985  6.518627  5.637814e-09 -6.927359e-11
# 2986  6.684675  3.136703e-09 -3.858517e-11
# 2987  6.853387  1.728594e-09 -2.128651e-11
# 2988  7.024776  9.435162e-10 -1.163055e-11
# 2989  7.198856  5.100615e-10 -6.293444e-12
# 2990  7.375637  2.730819e-10 -3.421738e-12
# 2991  7.555132  1.447908e-10 -1.672239e-12
# Cs_4p12 raw radial norm ∫(P²+Q²)dr = 1.0001590390531294
# Cs_4p12 fine radial norm after interpolation = 1.0000000000000004
# Cs_4p12 momentum norm ∫I(p)dp = 0.9999992998623309
# Cs_4p12 Compton check 2∫J(Q)dQ = 0.9999858967938807
#
# ======================
# Cs_4p32
# ======================
#                  r             P             Q
# 2992  1.818182e-08  3.779553e-13 -7.328778e-18
# 2993  1.993850e-08  4.542880e-13 -9.662649e-18
# 2994  2.186492e-08  5.461034e-13 -1.273873e-17
# 2995  2.397741e-08  6.565350e-13 -1.679384e-17
# 2996  2.629401e-08  7.893526e-13 -2.214036e-17
# 2997  2.883443e-08  9.490889e-13 -2.919012e-17
# 2998  3.162023e-08  1.141194e-12 -3.848601e-17
# 2999  3.467518e-08  1.372224e-12 -5.074427e-17
#              r             P             Q
# 3264  6.684675  8.001880e-09 -1.072554e-10
# 3265  6.853387  4.521921e-09 -6.049121e-11
# 3266  7.024776  2.531992e-09 -3.380604e-11
# 3267  7.198856  1.404724e-09 -1.871996e-11
# 3268  7.375637  7.721296e-10 -1.027079e-11
# 3269  7.555132  4.204762e-10 -5.583054e-12
# 3270  7.737355  2.268434e-10 -3.043785e-12
# 3271  7.922315  1.212346e-10 -1.515857e-12
# Cs_4p32 raw radial norm ∫(P²+Q²)dr = 1.0001542555812435
# Cs_4p32 fine radial norm after interpolation = 1.0000000000000002
# Cs_4p32 momentum norm ∫I(p)dp = 0.9999998203843747
# Cs_4p32 Compton check 2∫J(Q)dQ = 0.9999945094656696
#
# ======================
# Cs_4d32
# ======================
#                  r             P             Q
# 2124  1.818182e-08  4.103368e-19  2.001239e-14
# 2125  1.993850e-08  5.397446e-19  2.406513e-14
# 2126  2.186492e-08  7.106361e-19  2.894047e-14
# 2127  2.397741e-08  9.361937e-19  3.480295e-14
# 2128  2.629401e-08  1.233810e-18  4.185264e-14
# 2129  2.883443e-08  1.626424e-18  5.033059e-14
# 2130  3.162023e-08  2.144291e-18  6.052579e-14
# 2131  3.467518e-08  2.827315e-18  7.278602e-14
#               r             P             Q
# 2410   9.294670 -4.573179e-09  3.580326e-11
# 2411   9.501943 -2.801528e-09  2.198259e-11
# 2412   9.712054 -1.704608e-09  1.340465e-11
# 2413   9.925012 -1.030138e-09  8.117874e-12
# 2414  10.140828 -6.182953e-10  4.882348e-12
# 2415  10.359511 -3.685660e-10  2.916114e-12
# 2416  10.581071 -2.181937e-10  1.741939e-12
# 2417  10.805518 -1.282821e-10  9.900684e-13
# Cs_4d32 raw radial norm ∫(P²+Q²)dr = 1.0001432758422841
# Cs_4d32 fine radial norm after interpolation = 1.0
# Cs_4d32 momentum norm ∫I(p)dp = 0.9999999700920242
# Cs_4d32 Compton check 2∫J(Q)dQ = 0.9999998440599636
#
# ======================
# Cs_4d52
# ======================
#                  r             P             Q
# 2418  1.818182e-08  1.789473e-20 -2.481523e-25
# 2419  1.993850e-08  2.353818e-20 -3.585819e-25
# 2420  2.186492e-08  3.099074e-20 -5.178273e-25
# 2421  2.397741e-08  4.082729e-20 -7.478287e-25
# 2422  2.629401e-08  5.380628e-20 -1.080277e-24
# 2423  2.883443e-08  7.092815e-20 -1.560964e-24
# 2424  3.162023e-08  9.351231e-20 -2.256071e-24
# 2425  3.467518e-08  1.232990e-19 -3.261315e-24
#               r             P             Q
# 2706   9.712054 -2.382366e-09  2.289435e-11
# 2707   9.925012 -1.451000e-09  1.390974e-11
# 2708  10.140828 -8.778119e-10  8.394838e-12
# 2709  10.359511 -5.274719e-10  5.032647e-12
# 2710  10.581071 -3.148112e-10  2.996811e-12
# 2711  10.805518 -1.866137e-10  1.772512e-12
# 2712  11.032861 -1.098673e-10  1.047651e-12
# 2713  11.263111 -6.424142e-11  5.927158e-13
# Cs_4d52 raw radial norm ∫(P²+Q²)dr = 1.0001418023115265
# Cs_4d52 fine radial norm after interpolation = 0.9999999999999999
# Cs_4d52 momentum norm ∫I(p)dp = 0.9999999691907633
# Cs_4d52 Compton check 2∫J(Q)dQ = 0.999999874530616
#
# ======================
# Cs_5s12
# ======================
#                  r             P             Q
# 4236  1.818182e-08  6.824614e-07 -2.205177e-11
# 4237  1.993850e-08  7.483868e-07 -2.651638e-11
# 4238  2.186492e-08  8.206815e-07 -3.188547e-11
# 4239  2.397741e-08  8.999601e-07 -3.834213e-11
# 4240  2.629401e-08  9.868979e-07 -4.610674e-11
# 4241  2.883443e-08  1.082235e-06 -5.544423e-11
# 4242  3.162023e-08  1.186781e-06 -6.667296e-11
# 4243  3.467518e-08  1.301428e-06 -8.017621e-11
#               r             P             Q
# 4552  16.784721  2.742771e-09 -1.443101e-11
# 4553  17.081003  1.820287e-09 -9.574968e-12
# 4554  17.380373  1.202658e-09 -6.324582e-12
# 4555  17.682837  7.910307e-10 -4.158883e-12
# 4556  17.988401  5.179519e-10 -2.722501e-12
# 4557  18.297072  3.376190e-10 -1.774199e-12
# 4558  18.608857  2.190797e-10 -1.154157e-12
# 4559  18.923761  1.415179e-10 -7.361059e-13
# Cs_5s12 raw radial norm ∫(P²+Q²)dr = 1.0000725264400734
# Cs_5s12 fine radial norm after interpolation = 0.9999999999999998
# Cs_5s12 momentum norm ∫I(p)dp = 0.9999981418997779
# Cs_5s12 Compton check 2∫J(Q)dQ = 0.9999784086925867
#
# ======================
# Cs_5p12
# ======================
#                  r             P             Q
# 3546  1.818182e-08  3.630428e-12  1.067525e-07
# 3547  1.993850e-08  4.363639e-12  1.170648e-07
# 3548  2.186492e-08  5.245565e-12  1.283759e-07
# 3549  2.397741e-08  6.306310e-12  1.407794e-07
# 3550  2.629401e-08  7.582080e-12  1.543801e-07
# 3551  2.883443e-08  9.116416e-12  1.692957e-07
# 3552  3.162023e-08  1.096167e-11  1.856522e-07
# 3553  3.467518e-08  1.318081e-11  2.035887e-07
#               r             P             Q
# 3880  22.595330 -1.889080e-09  6.751179e-12
# 3881  22.948134 -1.316086e-09  4.709392e-12
# 3882  23.304133 -9.137088e-10  3.273609e-12
# 3883  23.663332 -6.321475e-10  2.267585e-12
# 3884  24.025736 -4.358269e-10  1.565213e-12
# 3885  24.391350 -2.994282e-10  1.076600e-12
# 3886  24.760180 -2.049992e-10  7.391572e-13
# 3887  25.132231 -1.398591e-10  5.011786e-13
# Cs_5p12 raw radial norm ∫(P²+Q²)dr = 1.0000630334459781
# Cs_5p12 fine radial norm after interpolation = 0.9999999999999999
# Cs_5p12 momentum norm ∫I(p)dp = 0.9999999189947624
# Cs_5p12 Compton check 2∫J(Q)dQ = 0.9999982362561823
#
# ======================
# Cs_5p32
# ======================
#                  r             P             Q
# 3888  1.818182e-08  1.307858e-13 -2.536027e-18
# 3889  1.993850e-08  1.571997e-13 -3.343632e-18
# 3890  2.186492e-08  1.889710e-13 -4.408071e-18
# 3891  2.397741e-08  2.271842e-13 -5.811287e-18
# 3892  2.629401e-08  2.731438e-13 -7.661378e-18
# 3893  2.883443e-08  3.284182e-13 -1.010085e-17
# 3894  3.162023e-08  3.948933e-13 -1.331757e-17
# 3895  3.467518e-08  4.748377e-13 -1.755938e-17
#               r             P             Q
# 4228  24.760180 -9.280565e-10  3.539451e-12
# 4229  25.132231 -6.480758e-10  2.470081e-12
# 4230  25.507507 -4.510623e-10  1.718112e-12
# 4231  25.886013 -3.128995e-10  1.191117e-12
# 4232  26.267755 -2.163360e-10  8.230353e-13
# 4233  26.652737 -1.490757e-10  5.668151e-13
# 4234  27.040963 -1.023851e-10  3.896341e-13
# 4235  27.432439 -7.008376e-11  2.648803e-13
# Cs_5p32 raw radial norm ∫(P²+Q²)dr = 1.0000599484355355
# Cs_5p32 fine radial norm after interpolation = 1.0000000000000002
# Cs_5p32 momentum norm ∫I(p)dp = 0.9999999780307585
# Cs_5p32 Compton check 2∫J(Q)dQ = 0.9999993257464319
#
# ======================
# Cs_6s12
# ======================
#                  r             P             Q
# 4560  1.818182e-08  1.654202e-07 -5.345080e-12
# 4561  1.993850e-08  1.813997e-07 -6.427246e-12
# 4562  2.186492e-08  1.989231e-07 -7.728649e-12
# 4563  2.397741e-08  2.181392e-07 -9.293664e-12
# 4564  2.629401e-08  2.392119e-07 -1.117571e-11
# 4565  2.883443e-08  2.623204e-07 -1.343901e-11
# 4566  3.162023e-08  2.876612e-07 -1.616071e-11
# 4567  3.467518e-08  3.154501e-07 -1.943374e-11
#               r             P             Q
# 4962  54.084727 -7.641342e-10  1.383651e-12
# 4963  54.664246 -5.792317e-10  1.049255e-12
# 4964  55.247213 -4.382484e-10  7.941785e-13
# 4965  55.833628 -3.309586e-10  5.999810e-13
# 4966  56.423494 -2.494663e-10  4.524172e-13
# 4967  57.016815 -1.876873e-10  3.405045e-13
# 4968  57.613591 -1.409428e-10  2.559188e-13
# 4969  58.213827 -1.056417e-10  1.915170e-13
# Cs_6s12 raw radial norm ∫(P²+Q²)dr = 1.0000191328213583
# Cs_6s12 fine radial norm after interpolation = 1.0000000000000002
# Cs_6s12 momentum norm ∫I(p)dp = 1.000000038640157
# Cs_6s12 Compton check 2∫J(Q)dQ = 0.9999990501297865
#
# Total Cs check 2∫Jtotal dQ = 54.95445274701164
# Expected close to 55
#            Q  J_1s1/2(2)  J_2s1/2(2)  J_2p1/2(2)  J_2p3/2(4)  J_3s1/2(2)  \
# 0       0.00    0.014634    0.052348    0.025901    0.027301    0.120523
# 1       0.05    0.014634    0.052346    0.025901    0.027301    0.120502
# 2       0.10    0.014634    0.052342    0.025901    0.027301    0.120440
# 3       0.15    0.014634    0.052335    0.025901    0.027301    0.120337
# 4       0.20    0.014634    0.052324    0.025901    0.027301    0.120192
# ...      ...         ...         ...         ...         ...         ...
# 1996   99.80    0.000285    0.000049    0.000007    0.000003    0.000010
# 1997   99.85    0.000284    0.000049    0.000007    0.000003    0.000010
# 1998   99.90    0.000284    0.000049    0.000007    0.000003    0.000010
# 1999   99.95    0.000283    0.000049    0.000007    0.000003    0.000010
# 2000  100.00    0.000283    0.000049    0.000007    0.000003    0.000010
#
#       J_3p1/2(2)    J_3p3/2(4)    J_3d3/2(4)    J_3d5/2(6)  J_4s1/2(2)  \
# 0       0.071203  7.384293e-02  4.885860e-02  4.945866e-02    0.263335
# 1       0.071203  7.384292e-02  4.885860e-02  4.945866e-02    0.263102
# 2       0.071203  7.384291e-02  4.885860e-02  4.945866e-02    0.262402
# 3       0.071203  7.384287e-02  4.885860e-02  4.945866e-02    0.261241
# 4       0.071203  7.384275e-02  4.885860e-02  4.945866e-02    0.259624
# ...          ...           ...           ...           ...         ...
# 1996    0.000002  7.281746e-07  1.278219e-08  7.945393e-09    0.000002
# 1997    0.000002  7.256828e-07  1.272945e-08  7.910502e-09    0.000002
# 1998    0.000002  7.232007e-07  1.267696e-08  7.875779e-09    0.000002
# 1999    0.000002  7.207282e-07  1.262471e-08  7.841222e-09    0.000002
# 2000    0.000002  7.182654e-07  1.257269e-08  7.806830e-09    0.000002
#
#         J_4p1/2(2)    J_4p3/2(4)    J_4d3/2(4)    J_4d5/2(4)    J_5s1/2(2)  \
# 0     1.688507e-01  1.753482e-01  1.428451e-01  1.446435e-01  6.962447e-01
# 1     1.688506e-01  1.753481e-01  1.428451e-01  1.446435e-01  6.922069e-01
# 2     1.688498e-01  1.753472e-01  1.428451e-01  1.446435e-01  6.802457e-01
# 3     1.688467e-01  1.753435e-01  1.428451e-01  1.446435e-01  6.608073e-01
# 4     1.688389e-01  1.753340e-01  1.428450e-01  1.446434e-01  6.346024e-01
# ...            ...           ...           ...           ...           ...
# 1996  3.366370e-07  1.575336e-07  2.862480e-09  1.879516e-09  3.773884e-07
# 1997  3.356246e-07  1.569938e-07  2.847685e-09  1.869151e-09  3.765985e-07
# 1998  3.346123e-07  1.564534e-07  2.832997e-09  1.858869e-09  3.758110e-07
# 1999  3.336003e-07  1.559127e-07  2.818443e-09  1.848691e-09  3.750255e-07
# 2000  3.325885e-07  1.553715e-07  2.804047e-09  1.838637e-09  3.742415e-07
#
#         J_5p1/2(2)    J_5p3/2(2)    J_6s1/2(1)  J_total_Cs_relativistic
# 0     4.966756e-01  5.252990e-01  2.621705e+00                11.579729
# 1     4.966551e-01  5.252715e-01  2.451887e+00                11.401172
# 2     4.964747e-01  5.250307e-01  2.008865e+00                10.931366
# 3     4.957977e-01  5.241319e-01  1.448798e+00                10.324906
# 4     4.941266e-01  5.219281e-01  9.274037e-01                 9.735345
# ...            ...           ...           ...                      ...
# 1996  4.222990e-08  1.905675e-08  2.067243e-08                 0.000727
# 1997  4.210466e-08  1.899245e-08  2.062919e-08                 0.000726
# 1998  4.197825e-08  1.892726e-08  2.058608e-08                 0.000724
# 1999  4.185059e-08  1.886113e-08  2.054308e-08                 0.000723
# 2000  4.172163e-08  1.879401e-08  2.050017e-08                 0.000721
#
# [2001 rows x 20 columns]
