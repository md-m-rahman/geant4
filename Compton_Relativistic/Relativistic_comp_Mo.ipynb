# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.special import spherical_jn
from scipy.integrate import cumulative_trapezoid

csv_file = "/root/geant4/fac/Mo_all_wavefunctions.csv"
df = pd.read_csv(csv_file)
df = df.dropna(subset=["r", "P", "Q"])

p = np.arange(0.0, 300.0 + 0.05, 0.05)
Qgrid = np.arange(0.0, 100.0 + 0.05, 0.05)

print(df["Orbital"].unique())


def get_orbital(df, name, print_values=True):
    d = df[df["Orbital"] == name].copy()
    d = d.sort_values("r")

    r_raw = d["r"].to_numpy()
    P_raw = d["P"].to_numpy()
    Q_raw = d["Q"].to_numpy()

    if print_values:
        print("\n======================")
        print(name)
        print("======================")
        print(d[["r", "P", "Q"]].head(8))
        print(d[["r", "P", "Q"]].tail(8))

    raw_norm = np.trapezoid(P_raw**2 + Q_raw**2, r_raw)
    print(name, "raw radial norm ∫(P²+Q²)dr =", raw_norm)

    # normalize raw FAC P,Q
    P_raw = P_raw / np.sqrt(raw_norm)
    Q_raw = Q_raw / np.sqrt(raw_norm)

    # interpolate to finer r grid
    r = np.linspace(r_raw.min(), r_raw.max(), 5000)
    P = np.interp(r, r_raw, P_raw)
    Qs = np.interp(r, r_raw, Q_raw)

    fine_norm = np.trapezoid(P**2 + Qs**2, r)
    P = P / np.sqrt(fine_norm)
    Qs = Qs / np.sqrt(fine_norm)

    print(name, "fine radial norm after interpolation =", np.trapezoid(P**2 + Qs**2, r))

    return r, P, Qs
   # return r_raw, P_raw, Q_raw

def chi_transform(p_grid, r, radial, l):
    chi = []

    for pp in p_grid:
        jl = spherical_jn(l, pp*r)

        # FAC P = rG, Q = rF
        # chi = sqrt(2/pi) int P(r) j_l(pr) r dr
        val = np.sqrt(2/np.pi) * np.trapezoid(radial * jl * r, r)

        chi.append(val)

    return np.array(chi)


def calculate_J(p_grid, chiG, chiF, Qgrid):
    integrand = (chiG**2 + chiF**2) * p_grid

    rev = cumulative_trapezoid(
        integrand[::-1],
        p_grid[::-1],
        initial=0
    )

    J_p = -0.5 * rev[::-1]
    J_Q = np.interp(Qgrid, p_grid, J_p)

    return J_Q


def one_orbital_J(df, name, l_large, l_small):
    r, P, Qs = get_orbital(df, name)

    chiG = chi_transform(p, r, P, l_large)
    chiF = chi_transform(p, r, Qs, l_small)

    I = (chiG**2 + chiF**2) * p**2
    print(name, "momentum norm ∫I(p)dp =", np.trapezoid(I, p))

    J = calculate_J(p, chiG, chiF, Qgrid)
    print(name, "Compton check 2∫J(Q)dQ =", 2*np.trapezoid(J, Qgrid))

    return J


# =====================================================
# Relativistic orbitals
# large component l = orbital l
# small component l' is decided by j
# =====================================================

J_1s12 = one_orbital_J(df, "Mo_1s12", 0, 1)

J_2s12 = one_orbital_J(df, "Mo_2s12", 0, 1)
J_2p12 = one_orbital_J(df, "Mo_2p12", 1, 0)
J_2p32 = one_orbital_J(df, "Mo_2p32", 1, 2)

J_3s12 = one_orbital_J(df, "Mo_3s12", 0, 1)
J_3p12 = one_orbital_J(df, "Mo_3p12", 1, 0)
J_3p32 = one_orbital_J(df, "Mo_3p32", 1, 2)

J_3d32 = one_orbital_J(df, "Mo_3d32", 2, 1)
J_3d52 = one_orbital_J(df, "Mo_3d52", 2, 3)

J_4s12 = one_orbital_J(df, "Mo_4s12", 0, 1)
J_4p12 = one_orbital_J(df, "Mo_4p12", 1, 0)
J_4p32 = one_orbital_J(df, "Mo_4p32", 1, 2)
J_4d32 = one_orbital_J(df, "Mo_4d32", 2, 1)
J_4d52 = one_orbital_J(df, "Mo_4d52", 2, 3)

J_5s12 = one_orbital_J(df, "Mo_5s12", 0, 1)

J_total_Mo_rel = (
    2*J_1s12
    + 2*J_2s12
    + 2*J_2p12 + 4*J_2p32
    + 2*J_3s12
    + 2*J_3p12 + 4*J_3p32
    + 4*J_3d32 + 6*J_3d52
    + 2*J_4s12
    + 2*J_4p12 + 4*J_4p32
    + 4*J_4d32 + 1*J_4d52
    + 1*J_5s12
)

print("\nTotal Mo check 2∫Jtotal dQ =", 2*np.trapezoid(J_total_Mo_rel, Qgrid))
print("Expected close to 40")


table = pd.DataFrame({
    "Q": Qgrid,
    "J_1s1/2(2)": 2*J_1s12,
    "J_2s1/2(2)": 2*J_2s12,
    "J_2p1/2(2)": 2*J_2p12,
    "J_2p3/2(4)": 4*J_2p32,
    "J_3s1/2(2)": 2*J_3s12,
    "J_3p1/2(2)": 2*J_3p12,
    "J_3p3/2(4)": 4*J_3p32,
    "J_3d3/2(4)": 4*J_3d32,
    "J_3d5/2(6)": 6*J_3d52,
    "J_4s1/2(2)": 2*J_4s12,
    "J_4p1/2(2)": 2*J_4p12,
    "J_4p3/2(4)": 4*J_4p32,
    "J_4d3/2(4)": 4*J_4d32,
    "J_4d5/2(1)": 1*J_4d32,
    "J_5s1/2(1)": 1*J_5s12,
    "J_total_Mo_relativistic": J_total_Mo_rel
})

table.to_csv("Mo_relativistic_Compton_profile.csv", index=False)
print(table)


plt.figure(figsize=(8,6))
plt.plot(Qgrid, 2*J_1s12, label="1s1/2(2)")
plt.plot(Qgrid, 2*J_2s12, label="2s1/2(2)")
plt.plot(Qgrid, 2*J_2p12 + 4*J_2p32, label="2p(6)")
plt.plot(Qgrid, 2*J_3s12, label="3s1/2(2)")
plt.plot(Qgrid, 2*J_3p12 + 4*J_3p32, label="3p(6)")
plt.plot(Qgrid, 4*J_3d32 + 6*J_3d52, label="3d(10)")
plt.plot(Qgrid, 2*J_4s12, label="4s1/2(2)")
plt.plot(Qgrid, 2*J_4p12 + 4*J_4p32, label="4p(6)")
plt.plot(Qgrid, 4*J_4d32 + 1*J_4d52, label="4d(5)")
plt.plot(Qgrid, 2*J_5s12, label="5s(1)")
plt.plot(Qgrid, J_total_Mo_rel, label="Mo total relativistic", linewidth=2)

plt.xlabel("Q (a.u.)")
plt.ylabel("J(Q)")
plt.title("Relativistic Molybdenum Compton Profile")
plt.yscale("log")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# ['Mo_1s12' 'Mo_2p12' 'Mo_2p32' 'Mo_2s12' 'Mo_3d32' 'Mo_3d52' 'Mo_3p12'
#  'Mo_3p32' 'Mo_3s12' 'Mo_4d32' 'Mo_4d52' 'Mo_4p12' 'Mo_4p32' 'Mo_4s12'
#  'Mo_5s12']
# 435  1.805396  1.205574e-09 -5.683870e-11
# 436  1.875879  4.572701e-10 -2.386985e-11
# 437  1.948284  1.688142e-10 -2.094491e-12
# Mo_2p12 raw radial norm ∫(P²+Q²)dr = 1.0004626051234624
# Mo_2p12 fine radial norm after interpolation = 1.0000000000000002
# Mo_2p12 momentum norm ∫I(p)dp = 0.999998580768291
# Mo_2p12 Compton check 2∫J(Q)dQ = 0.9999637498082791
#
# ======================
# Mo_2p32
# ======================
#                 r             P             Q
# 438  2.380952e-08  1.302904e-12 -2.773996e-17
# 439  2.610908e-08  1.565940e-12 -3.657123e-17
# 440  2.863074e-08  1.882306e-12 -4.820971e-17
# 441  3.139593e-08  2.262795e-12 -6.355099e-17
# 442  3.442814e-08  2.720381e-12 -8.377545e-17
# 443  3.775319e-08  3.270672e-12 -1.104401e-16
# 444  4.139931e-08  3.932428e-12 -1.455968e-16
# 445  4.539748e-08  4.728213e-12 -1.919515e-16
#             r             P             Q
# 662  1.605238  2.997296e-08 -1.589682e-09
# 663  1.670100  1.253893e-08 -6.620731e-10
# 664  1.736811  5.113446e-09 -2.687598e-10
# 665  1.805396  2.032120e-09 -1.063001e-10
# 666  1.875879  7.867350e-10 -4.095065e-11
# 667  1.948284  2.966275e-10 -1.536002e-11
# 668  2.022634  1.088826e-10 -6.242193e-12
# 669  2.098955  3.889827e-11 -3.985914e-13
# Mo_2p32 raw radial norm ∫(P²+Q²)dr = 1.000453980053933
# Mo_2p32 fine radial norm after interpolation = 1.0
# Mo_2p32 momentum norm ∫I(p)dp = 0.9999997189919024
# Mo_2p32 Compton check 2∫J(Q)dQ = 0.9999845761701559
#
# ======================
# Mo_3s12
# ======================
#                  r         P             Q
# 1956  2.380952e-08  0.000002 -8.410885e-11
# 1957  2.610908e-08  0.000003 -1.011327e-10
# 1958  2.863074e-08  0.000003 -1.216039e-10
# 1959  3.139593e-08  0.000003 -1.462205e-10
# 1960  3.442814e-08  0.000003 -1.758212e-10
# 1961  3.775319e-08  0.000004 -2.114156e-10
# 1962  4.139931e-08  0.000004 -2.542164e-10
# 1963  4.539748e-08  0.000005 -3.056826e-10
#              r             P             Q
# 2204  3.718991  2.494877e-08 -5.604806e-10
# 2205  3.834428  1.260174e-08 -2.826729e-10
# 2206  3.952223  6.275644e-09 -1.405562e-10
# 2207  4.072394  3.080986e-09 -6.889914e-11
# 2208  4.194958  1.491013e-09 -3.329131e-11
# 2209  4.319931  7.111978e-10 -1.585466e-11
# 2210  4.447331  3.343289e-10 -7.673779e-12
# 2211  4.577175  1.548779e-10 -2.876007e-12
# Mo_3s12 raw radial norm ∫(P²+Q²)dr = 1.0002325971268278
# Mo_3s12 fine radial norm after interpolation = 0.9999999999999999
# Mo_3s12 momentum norm ∫I(p)dp = 0.9999901357468736
# Mo_3s12 Compton check 2∫J(Q)dQ = 0.9998698637136889
#
# ======================
# Mo_3p12
# ======================
#                  r             P             Q
# 1436  2.380952e-08  1.173436e-11  3.114560e-07
# 1437  2.610908e-08  1.410334e-11  3.415363e-07
# 1438  2.863074e-08  1.695264e-11  3.745205e-07
# 1166  6.171170  1.815636e-10 -2.533175e-12
# 1167  6.331529  9.409700e-11 -1.182701e-12
# Mo_3d32 raw radial norm ∫(P²+Q²)dr = 1.000238065274462
# Mo_3d32 fine radial norm after interpolation = 0.9999999999999998
# Mo_3d32 momentum norm ∫I(p)dp = 0.9999999648461445
# Mo_3d32 Compton check 2∫J(Q)dQ = 0.9999999310410456
#
# ======================
# Mo_3d52
# ======================
#                  r             P             Q
# 1168  2.380952e-08  2.583441e-20 -3.936742e-25
# 1169  2.610908e-08  3.397857e-20 -5.688085e-25
# 1170  2.863074e-08  4.473239e-20 -8.213237e-25
# 1171  3.139593e-08  5.892486e-20 -1.185992e-24
# 1172  3.442814e-08  7.764943e-20 -1.713009e-24
# 1173  3.775319e-08  1.023484e-19 -2.474919e-24
# 1174  4.139931e-08  1.349236e-19 -3.576548e-24
# 1175  4.539748e-08  1.778832e-19 -5.169448e-24
#              r             P             Q
# 1428  5.263599  8.740741e-09 -1.475707e-10
# 1429  5.408433  4.849325e-09 -8.158342e-11
# 1430  5.555820  2.662609e-09 -4.464159e-11
# 1431  5.705772  1.446767e-09 -2.417593e-11
# 1432  5.858306  7.779063e-10 -1.295696e-11
# 1433  6.013434  4.138727e-10 -6.871788e-12
# 1434  6.171170  2.178665e-10 -3.656285e-12
# 1435  6.331529  1.134676e-10 -1.753148e-12
# Mo_3d52 raw radial norm ∫(P²+Q²)dr = 1.00023647200168
# Mo_3d52 fine radial norm after interpolation = 0.9999999999999999
# Mo_3d52 momentum norm ∫I(p)dp = 0.9999999652695729
# Mo_3d52 Compton check 2∫J(Q)dQ = 0.9999999391115233
#
# ======================
# Mo_4s12
# ======================
#                  r             P             Q
# 3588  2.380952e-08  9.833710e-07 -3.486733e-11
# 3589  2.610908e-08  1.078329e-06 -4.192457e-11
# 3590  2.863074e-08  1.182457e-06 -5.041092e-11
# 3591  3.139593e-08  1.296642e-06 -6.061573e-11
# 3592  3.442814e-08  1.421853e-06 -7.288669e-11
# 3593  3.775319e-08  1.559156e-06 -8.764235e-11
# 3594  4.139931e-08  1.709718e-06 -1.053854e-10
# 3595  4.539748e-08  1.874818e-06 -1.267207e-10
#               r             P             Q
# 3878  10.772042 -2.386857e-09  1.973350e-11
# 3879  10.998938 -1.456633e-09  1.203611e-11
# 3880  11.228738 -8.831706e-10  7.293619e-12
# 3881  11.461452 -5.319871e-10  4.391023e-12
# 3882  11.697087 -3.183547e-10  2.626307e-12
# 3883  11.935654 -1.892634e-10  1.560536e-12
# 3884  12.177160 -1.117788e-10  9.271126e-13
# 3885  12.421616 -6.558143e-11  5.262889e-13
# Mo_4s12 raw radial norm ∫(P²+Q²)dr = 1.0001108037675797
# Mo_4s12 fine radial norm after interpolation = 1.0
# Mo_4s12 momentum norm ∫I(p)dp = 0.9999982994615938
# Mo_4s12 Compton check 2∫J(Q)dQ = 0.9999775139763657
#
# ======================
# Mo_4p12
# ======================
#                  r             P             Q
# 2970  2.380952e-08  4.531804e-12  1.202817e-07
# 2971  2.610908e-08  5.446704e-12  1.318985e-07
# 2972  2.863074e-08  6.547101e-12  1.446367e-07
# 2587  41.127186 -1.722721e-10  3.480146e-13
# 2588  41.624283 -1.276788e-10  2.585524e-13
# 2589  42.124756 -9.441760e-11  1.910284e-13
# Mo_4d32 raw radial norm ∫(P²+Q²)dr = 1.0000698940405266
# Mo_4d32 fine radial norm after interpolation = 1.0000000000000002
# Mo_4d32 momentum norm ∫I(p)dp = 0.9999999972714317
# Mo_4d32 Compton check 2∫J(Q)dQ = 0.9999999877987236
#
# ======================
# Mo_4d52
# ======================
#                  r             P             Q
# 2590  2.380952e-08  6.987714e-21 -1.063502e-25
# 2591  2.610908e-08  9.190552e-21 -1.536624e-25
# 2592  2.863074e-08  1.209925e-20 -2.218788e-25
# 2593  3.139593e-08  1.593805e-20 -3.203931e-25
# 2594  3.442814e-08  2.100268e-20 -4.627656e-25
# 2595  3.775319e-08  2.768327e-20 -6.685939e-25
# 2596  4.139931e-08  3.649425e-20 -9.661964e-25
# 2597  4.539748e-08  4.811399e-20 -1.396515e-24
#               r             P             Q
# 2962  39.656124 -7.186603e-10  1.739392e-12
# 2963  40.143110 -5.397148e-10  1.305309e-12
# 2964  40.633463 -4.044411e-10  9.774292e-13
# 2965  41.127186 -3.024097e-10  7.303189e-13
# 2966  41.624283 -2.256240e-10  5.444955e-13
# 2967  42.124756 -1.679666e-10  4.050696e-13
# 2968  42.628610 -1.247694e-10  3.008453e-13
# 2969  43.135847 -9.247843e-11  2.223742e-13
# Mo_4d52 raw radial norm ∫(P²+Q²)dr = 1.0000688331437615
# Mo_4d52 fine radial norm after interpolation = 1.0
# Mo_4d52 momentum norm ∫I(p)dp = 0.9999999976716839
# Mo_4d52 Compton check 2∫J(Q)dQ = 0.9999999889971826
#
# ======================
# Mo_5s12
# ======================
#                  r             P             Q
# 3886  2.380952e-08  2.558470e-07 -9.071580e-12
# 3887  2.610908e-08  2.805524e-07 -1.090769e-11
# 3888  2.863074e-08  3.076439e-07 -1.311562e-11
# 3889  3.139593e-08  3.373517e-07 -1.577065e-11
# 3890  3.442814e-08  3.699283e-07 -1.896323e-11
# 3891  3.775319e-08  4.056510e-07 -2.280228e-11
# 3892  4.139931e-08  4.448232e-07 -2.741857e-11
# 3893  4.539748e-08  4.877778e-07 -3.296946e-11
#               r             P             Q
# 4260  40.633463  9.082715e-10 -2.111376e-12
# 4261  41.127186  6.711288e-10 -1.560512e-12
# 4262  41.624283  4.947650e-10 -1.150720e-12
# 4263  42.124756  3.639103e-10 -8.465883e-13
# 4264  42.628610  2.670494e-10 -6.214050e-13
# 4265  43.135847  1.955197e-10 -4.550684e-13
# 4266  43.646470  1.428204e-10 -3.327278e-13
# 4267  44.160482  1.040855e-10 -2.418380e-13
# Mo_5s12 raw radial norm ∫(P²+Q²)dr = 1.0000324121115718
# Mo_5s12 fine radial norm after interpolation = 0.9999999999999998
# Mo_5s12 momentum norm ∫I(p)dp = 0.9999999594169585
# Mo_5s12 Compton check 2∫J(Q)dQ = 0.9999986124774265
#
# Total Mo check 2∫Jtotal dQ = 41.98718599338746
# Expected close to 40
#            Q  J_1s1/2(2)  J_2s1/2(2)  J_2p1/2(2)  J_2p3/2(4)  J_3s1/2(2)  \
