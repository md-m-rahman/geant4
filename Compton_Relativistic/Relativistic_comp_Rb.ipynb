# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.special import spherical_jn
from scipy.integrate import cumulative_trapezoid

csv_file = "/root/geant4/fac/Rb_all_wavefunctions.csv"
df = pd.read_csv(csv_file)
df = df.dropna(subset=["r", "P", "Q"])

p = np.arange(0.0, 300.0 + 0.05, 0.05)
Qgrid = np.arange(0.0, 100.0 + 0.05, 0.05)

print(df["Orbital"].unique())


def get_orbital(df, name, print_values=True):
    d = df[df["Orbital"] == name].copy()
    d = d.sort_values("r")

    r_raw = d["r"].to_numpy()
    P_raw = d["P"].to_numpy()
    Q_raw = d["Q"].to_numpy()

    if print_values:
        print("\n======================")
        print(name)
        print("======================")
        print(d[["r", "P", "Q"]].head(8))
        print(d[["r", "P", "Q"]].tail(8))

    raw_norm = np.trapezoid(P_raw**2 + Q_raw**2, r_raw)
    print(name, "raw radial norm ∫(P²+Q²)dr =", raw_norm)

    # normalize raw FAC P,Q
    P_raw = P_raw / np.sqrt(raw_norm)
    Q_raw = Q_raw / np.sqrt(raw_norm)

    # interpolate to finer r grid
    r = np.linspace(r_raw.min(), r_raw.max(), 5000)
    P = np.interp(r, r_raw, P_raw)
    Qs = np.interp(r, r_raw, Q_raw)

    fine_norm = np.trapezoid(P**2 + Qs**2, r)
    P = P / np.sqrt(fine_norm)
    Qs = Qs / np.sqrt(fine_norm)

    print(name, "fine radial norm after interpolation =", np.trapezoid(P**2 + Qs**2, r))

    return r, P, Qs
   # return r_raw, P_raw, Q_raw

def chi_transform(p_grid, r, radial, l):
    chi = []

    for pp in p_grid:
        jl = spherical_jn(l, pp*r)

        # FAC P = rG, Q = rF
        # chi = sqrt(2/pi) int P(r) j_l(pr) r dr
        val = np.sqrt(2/np.pi) * np.trapezoid(radial * jl * r, r)

        chi.append(val)

    return np.array(chi)


def calculate_J(p_grid, chiG, chiF, Qgrid):
    integrand = (chiG**2 + chiF**2) * p_grid

    rev = cumulative_trapezoid(
        integrand[::-1],
        p_grid[::-1],
        initial=0
    )

    J_p = -0.5 * rev[::-1]
    J_Q = np.interp(Qgrid, p_grid, J_p)

    return J_Q


def one_orbital_J(df, name, l_large, l_small):
    r, P, Qs = get_orbital(df, name)

    chiG = chi_transform(p, r, P, l_large)
    chiF = chi_transform(p, r, Qs, l_small)

    I = (chiG**2 + chiF**2) * p**2
    print(name, "momentum norm ∫I(p)dp =", np.trapezoid(I, p))

    J = calculate_J(p, chiG, chiF, Qgrid)
    print(name, "Compton check 2∫J(Q)dQ =", 2*np.trapezoid(J, Qgrid))

    return J


# =====================================================
# Relativistic orbitals
# large component l = orbital l
# small component l' is decided by j
# =====================================================

J_1s12 = one_orbital_J(df, "Rb_1s12", 0, 1)

J_2s12 = one_orbital_J(df, "Rb_2s12", 0, 1)
J_2p12 = one_orbital_J(df, "Rb_2p12", 1, 0)
J_2p32 = one_orbital_J(df, "Rb_2p32", 1, 2)

J_3s12 = one_orbital_J(df, "Rb_3s12", 0, 1)
J_3p12 = one_orbital_J(df, "Rb_3p12", 1, 0)
J_3p32 = one_orbital_J(df, "Rb_3p32", 1, 2)

J_3d32 = one_orbital_J(df, "Rb_3d32", 2, 1)
J_3d52 = one_orbital_J(df, "Rb_3d52", 2, 3)

J_4s12 = one_orbital_J(df, "Rb_4s12", 0, 1)
J_4p12 = one_orbital_J(df, "Rb_4p12", 1, 0)
J_4p32 = one_orbital_J(df, "Rb_4p32", 1, 2)

J_5s12 = one_orbital_J(df, "Rb_5s12", 0, 1)

J_total_Rb_rel = (
    2*J_1s12
    + 2*J_2s12
    + 2*J_2p12 + 4*J_2p32
    + 2*J_3s12
    + 2*J_3p12 + 4*J_3p32
    + 4*J_3d32 + 6*J_3d52
    + 2*J_4s12
    + 2*J_4p12 + 4*J_4p32
    + 1*J_5s12
)

print("\nTotal Rb check 2∫Jtotal dQ =", 2*np.trapezoid(J_total_Rb_rel, Qgrid))
print("Expected close to 37")


table = pd.DataFrame({
    "Q": Qgrid,
    "J_1s1/2(2)": 2*J_1s12,
    "J_2s1/2(2)": 2*J_2s12,
    "J_2p1/2(2)": 2*J_2p12,
    "J_2p3/2(4)": 4*J_2p32,
    "J_3s1/2(2)": 2*J_3s12,
    "J_3p1/2(2)": 2*J_3p12,
    "J_3p3/2(4)": 4*J_3p32,
    "J_3d3/2(4)": 4*J_3d32,
    "J_3d5/2(6)": 6*J_3d52,
    "J_4s1/2(2)": 2*J_4s12,
    "J_4p1/2(2)": 2*J_4p12,
    "J_4p3/2(4)": 4*J_4p32,
    "J_5s1/2(1)": 1*J_5s12,
    "J_total_Rb_relativistic": J_total_Rb_rel
})

table.to_csv("Rubidium_relativistic_Compton_profile.csv", index=False)
print(table)


plt.figure(figsize=(8,6))
plt.plot(Qgrid, 2*J_1s12, label="1s1/2(2)")
plt.plot(Qgrid, 2*J_2s12, label="2s1/2(2)")
plt.plot(Qgrid, 2*J_2p12 + 4*J_2p32, label="2p(6)")
plt.plot(Qgrid, 2*J_3s12, label="3s1/2(2)")
plt.plot(Qgrid, 2*J_3p12 + 4*J_3p32, label="3p(6)")
plt.plot(Qgrid, 4*J_3d32 + 6*J_3d52, label="3d(10)")
plt.plot(Qgrid, 2*J_4s12, label="4s1/2(2)")
plt.plot(Qgrid, 2*J_4p12 + 4*J_4p32, label="4p(6)")
plt.plot(Qgrid, 1*J_5s12, label="5s(1)")
plt.plot(Qgrid, J_total_Rb_rel, label="Rb total relativistic", linewidth=2)

plt.xlabel("Q (a.u.)")
plt.ylabel("J(Q)")
plt.title("Relativistic Rubidium Compton Profile")
plt.yscale("log")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# ['Rb_1s12' 'Rb_2p12' 'Rb_2p32' 'Rb_2s12' 'Rb_3d32' 'Rb_3d52' 'Rb_3p12'
#  'Rb_3p32' 'Rb_3s12' 'Rb_4p12' 'Rb_4p32' 'Rb_4s12' 'Rb_5s12']
#
# ======================
# Rb_1s12
# ======================
#               r         P             Q
# 0  2.702703e-08  0.000015 -5.583159e-10
# 1  2.963687e-08  0.000016 -6.713046e-10
# 2  3.249874e-08  0.000018 -8.071691e-10
# 3  3.563695e-08  0.000020 -9.705402e-10
# 4  3.907814e-08  0.000022 -1.166982e-09
# 5  4.285155e-08  0.000024 -1.403189e-09
# 6  4.698931e-08  0.000026 -1.687213e-09
# 7  5.152662e-08  0.000029 -2.028736e-09
#             r             P             Q
# 200  0.572888  4.063746e-07 -5.085687e-08
# 201  0.603074  1.514671e-07 -1.885455e-08
# 202  0.634481  5.416863e-08 -6.701621e-09
# 203  0.667139  1.856855e-08 -2.281063e-09
# 204  0.701078  6.094893e-09 -7.426171e-10
# 205  0.736326  1.913651e-09 -2.309495e-10
# 206  0.772913  5.741325e-10 -8.728532e-11
# 207  0.810869  1.644184e-10  2.823593e-11
# Rb_1s12 raw radial norm ∫(P²+Q²)dr = 1.0007343814631786
# Rb_1s12 fine radial norm after interpolation = 0.9999999999999999
# Rb_1s12 momentum norm ∫I(p)dp = 0.9997647664266867
# Rb_1s12 Compton check 2∫J(Q)dQ = 0.9969919476917432
#
# ======================
# Rb_2s12
# ======================
#                 r         P             Q
# 676  2.702703e-08  0.000005 -1.816382e-10
# 677  2.963687e-08  0.000005 -2.183971e-10
# 678  3.249874e-08  0.000006 -2.625982e-10
# 679  3.563695e-08  0.000006 -3.157481e-10
# 680  3.907814e-08  0.000007 -3.796571e-10
# 681  4.285155e-08  0.000008 -4.565027e-10
# 682  4.698931e-08  0.000008 -5.489051e-10
# 683  5.152662e-08  0.000009 -6.600134e-10
#             r             P             Q
# 900  1.692823 -1.178904e-07  5.411549e-09
# 901  1.760171 -5.223331e-08  2.392024e-09
# 902  1.829400 -2.260669e-08  1.032679e-09
# 903  1.900536 -9.554863e-09  4.353036e-10
# 904  1.973602 -3.942646e-09  1.791083e-10
# 905  2.048622 -1.587834e-09  7.191263e-11
# 906  2.125619 -6.239574e-10  3.045867e-11
# 907  2.204616 -2.391750e-10  5.066270e-12
# Rb_2s12 raw radial norm ∫(P²+Q²)dr = 1.0003978158248668
# Rb_2s12 fine radial norm after interpolation = 0.9999999999999998
# Rb_2s12 momentum norm ∫I(p)dp = 0.9999740295363981
# Rb_2s12 Compton check 2∫J(Q)dQ = 0.9996373914178103
#
# ======================
# Rb_2p12
# ======================
#                 r             P             Q
# 208  2.702703e-08  2.148015e-11  5.386858e-07
# 209  2.963687e-08  2.581586e-11  5.907024e-07
# 210  3.249874e-08  3.103046e-11  6.477397e-07
# 211  3.563695e-08  3.730178e-11  7.102873e-07
# 212  3.907814e-08  4.484360e-11  7.788792e-07
# 213  4.285155e-08  5.391300e-11  8.540891e-07
# 214  4.698931e-08  6.481918e-11  9.365533e-07
# 215  5.152662e-08  7.793386e-11  1.026992e-06
#             r             P             Q
# 434  1.829400  3.543566e-08 -1.410146e-09
# 435  1.900536  1.556955e-08 -6.201857e-10
# 436  1.973602  6.686473e-09 -2.665180e-10
# 437  2.048622  2.805998e-09 -1.118818e-10
# 438  2.125619  1.150353e-09 -4.586711e-11
# 439  2.204616  4.605886e-10 -1.835827e-11
# 440  2.285637  1.800607e-10 -7.848636e-12
# 441  2.368703  6.871264e-11 -1.041781e-12
# Rb_2p12 raw radial norm ∫(P²+Q²)dr = 1.0004299418246585
# Rb_2p12 fine radial norm after interpolation = 0.9999999999999999
# Rb_3d32 momentum norm ∫I(p)dp = 0.9999999817827242
# Rb_3d32 Compton check 2∫J(Q)dQ = 0.9999999653476599
#
# ======================
# Rb_3d52
# ======================
#                  r             P             Q
# 1190  2.702703e-08  2.031829e-20 -3.262781e-25
# 1191  2.963687e-08  2.672230e-20 -4.714077e-25
# 1192  3.249874e-08  3.517797e-20 -6.806464e-25
# 1193  3.563695e-08  4.633689e-20 -9.827972e-25
# 1194  3.907814e-08  6.105850e-20 -1.419435e-24
# 1195  4.285155e-08  8.047628e-20 -2.050631e-24
# 1196  4.698931e-08  1.060850e-19 -2.963222e-24
# 1197  5.152662e-08  1.398559e-19 -4.282724e-24
#              r             P             Q
# 1464  7.773018  3.088553e-09 -3.594685e-11
# 1465  7.958487  1.834516e-09 -2.129073e-11
# 1466  8.146709  1.081206e-09 -1.251337e-11
# 1467  8.337693  6.322656e-10 -7.297861e-12
# 1468  8.531452  3.668431e-10 -4.223157e-12
# 1469  8.727996  2.111717e-10 -2.424841e-12
# 1470  8.927338  1.206010e-10 -1.391998e-12
# 1471  9.129486  6.833001e-11 -7.558376e-13
# Rb_3d52 raw radial norm ∫(P²+Q²)dr = 1.0002029630085782
# Rb_3d52 fine radial norm after interpolation = 1.0
# Rb_3d52 momentum norm ∫I(p)dp = 0.9999999820566778
# Rb_3d52 Compton check 2∫J(Q)dQ = 0.9999999673755915
#
# ======================
# Rb_4s12
# ======================
#                  r             P             Q
# 2938  2.702703e-08  7.256983e-07 -2.711267e-11
# 2939  2.963687e-08  7.957618e-07 -3.259958e-11
# 2940  3.249874e-08  8.725906e-07 -3.919737e-11
# 2941  3.563695e-08  9.568378e-07 -4.713093e-11
# 2942  3.907814e-08  1.049219e-06 -5.667045e-11
# 2943  4.285155e-08  1.150519e-06 -6.814100e-11
# 2944  4.698931e-08  1.261601e-06 -8.193368e-11
# 2945  5.152662e-08  1.383407e-06 -9.851854e-11
#               r             P             Q
# 3244  15.124156 -2.347479e-09  1.368274e-11
# 3245  15.402612 -1.531864e-09  8.925909e-12
# 3246  15.684114 -9.947638e-10  5.794491e-12
# 3247  15.968671 -6.428302e-10  3.743321e-12
# 3248  16.256287 -4.133754e-10  2.406428e-12
# 3249  16.546972 -2.645213e-10  1.539425e-12
# 3250  16.840731 -1.684380e-10  9.831887e-13
# 3251  17.137571 -1.067281e-10  6.133328e-13
# Rb_4s12 raw radial norm ∫(P²+Q²)dr = 1.0000869918045965
# Rb_4s12 fine radial norm after interpolation = 1.0
# Rb_4s12 momentum norm ∫I(p)dp = 0.9999994043193179
# Rb_4s12 Compton check 2∫J(Q)dQ = 0.9999917153167498
#
# ======================
# Rb_4p12
# ======================
#                  r             P             Q
# 2272  2.702703e-08  2.857410e-12  7.165106e-08
# 2273  2.963687e-08  3.434170e-12  7.856984e-08
# 2274  3.249874e-08  4.127846e-12  8.615642e-08
# 2275  3.563695e-08  4.962092e-12  9.447594e-08
# 2276  3.907814e-08  5.965346e-12  1.035994e-07
# 2277  4.285155e-08  7.171809e-12  1.136031e-07
# 2278  4.698931e-08  8.622609e-12  1.245718e-07
# 2279  5.152662e-08  1.036720e-11  1.366011e-07
#               r             P             Q
# 2596  20.608050  1.782527e-09 -6.929745e-12
# 2597  20.942367  1.227928e-09 -4.779754e-12
# 2598  21.279847  8.427342e-10 -3.284444e-12
# 2599  21.620495  5.762183e-10 -2.248454e-12
# 2600  21.964317  3.925179e-10 -1.533450e-12
# 2601  22.311318  2.663823e-10 -1.041877e-12
# 2602  22.661503  1.801036e-10 -7.065815e-13
# 2603  23.014879  1.213132e-10 -4.724449e-13
# Rb_4p12 raw radial norm ∫(P²+Q²)dr = 1.0000763512906903
# Rb_4p12 fine radial norm after interpolation = 0.9999999999999998
# Rb_4p12 momentum norm ∫I(p)dp = 0.9999999744353135
# Rb_4p12 Compton check 2∫J(Q)dQ = 0.999999713144654
#
# ======================
# Rb_4p32
# ======================
#                  r             P             Q
# 2604  2.702703e-08  1.531673e-13 -3.434438e-18
# 2605  2.963687e-08  1.840837e-13 -4.527666e-18
# 2606  3.249874e-08  2.212672e-13 -5.968321e-18
# 2607  3.563695e-08  2.659858e-13 -7.867227e-18
# 2608  3.907814e-08  3.197639e-13 -1.037043e-17
# 2609  4.285155e-08  3.844347e-13 -1.367053e-17
# 2610  4.698931e-08  4.622029e-13 -1.802149e-17
# 2611  5.152662e-08  5.557192e-13 -2.375814e-17
#               r             P             Q
# 2930  21.279847  1.606076e-09 -6.903850e-12
# 2931  21.620495  1.109845e-09 -4.767082e-12
# 2932  21.964317  7.641440e-10 -3.279726e-12
# 2933  22.311318  5.242062e-10 -2.248244e-12
# 2934  22.661503  3.582951e-10 -1.535563e-12
# 2935  23.014879  2.439995e-10 -1.044980e-12
# 2936  23.371450  1.655556e-10 -7.097083e-13
# 2937  23.731222  1.119190e-10 -4.759987e-13
# Rb_4p32 raw radial norm ∫(P²+Q²)dr = 1.0000746523671038
# Rb_4p32 fine radial norm after interpolation = 1.0
# Rb_4p32 momentum norm ∫I(p)dp = 0.999999982458934
# Rb_4p32 Compton check 2∫J(Q)dQ = 0.9999998544626272
#
# ======================
# Rb_5s12
# ======================
#                  r             P             Q
# 3252  2.702703e-08  1.676723e-07 -6.264378e-12
# 3253  2.963687e-08  1.838605e-07 -7.532127e-12
# 3254  3.249874e-08  2.016117e-07 -9.056546e-12
# 3255  3.563695e-08  2.210771e-07 -1.088959e-11
# 3256  3.907814e-08  2.424217e-07 -1.309370e-11
# 3257  4.285155e-08  2.658271e-07 -1.574397e-11
# 3258  4.698931e-08  2.914924e-07 -1.893076e-11
# 3259  5.152662e-08  3.196358e-07 -2.276269e-11
#               r             P             Q
# 3644  50.782383  8.229463e-10 -1.571100e-12
# 3645  51.341877  6.207959e-10 -1.185608e-12
# 3646  51.904802  4.673864e-10 -8.929464e-13
# 3647  52.471161  3.511987e-10 -6.712074e-13
# 3648  53.040956  2.633779e-10 -5.035410e-13
# 3649  53.614189  1.971310e-10 -3.770159e-13
# 3650  54.190864  1.472582e-10 -2.818777e-13
# 3651  54.770984  1.097876e-10 -2.097813e-13
# Rb_5s12 raw radial norm ∫(P²+Q²)dr = 1.0000218962280494
# Rb_5s12 fine radial norm after interpolation = 1.0
# Rb_5s12 momentum norm ∫I(p)dp = 1.0000000053103466
# Rb_5s12 Compton check 2∫J(Q)dQ = 0.9999996317863048
#
# Total Rb check 2∫Jtotal dQ = 36.993053571964815
# Expected close to 37
#            Q  J_1s1/2(2)  J_2s1/2(2)    J_2p1/2(2)    J_2p3/2(4)  J_3s1/2(2)  \
# 0       0.00    0.045511    0.167093  8.361241e-02  1.711548e-01    0.428705
# 1       0.05    0.045511    0.167081  8.361241e-02  1.711548e-01    0.428479
# 2       0.10    0.045510    0.167046  8.361241e-02  1.711548e-01    0.427803
# 3       0.15    0.045509    0.166987  8.361240e-02  1.711548e-01    0.426679
# 4       0.20    0.045507    0.166904  8.361238e-02  1.711548e-01    0.425110
# ...      ...         ...         ...           ...           ...         ...
# 1996   99.80    0.000112    0.000014  7.222500e-07  7.652713e-07    0.000002
# 1997   99.85    0.000112    0.000014  7.199268e-07  7.625180e-07    0.000002
# 1998   99.90    0.000112    0.000014  7.176124e-07  7.597761e-07    0.000002
# 1999   99.95    0.000111    0.000014  7.153066e-07  7.570453e-07    0.000002
# 2000  100.00    0.000111    0.000014  7.130095e-07  7.543256e-07    0.000002
#
#         J_3p1/2(2)    J_3p3/2(4)    J_3d3/2(4)    J_3d5/2(6)    J_4s1/2(2)  \
# 0     2.573504e-01  5.248738e-01  3.779124e-01  5.707652e-01  1.223260e+00
# 1     2.573504e-01  5.248737e-01  3.779124e-01  5.707652e-01  1.218070e+00
# 2     2.573500e-01  5.248728e-01  3.779124e-01  5.707652e-01  1.202647e+00
# 3     2.573484e-01  5.248693e-01  3.779124e-01  5.707652e-01  1.177419e+00
# 4     2.573443e-01  5.248603e-01  3.779124e-01  5.707652e-01  1.143079e+00
# ...            ...           ...           ...           ...           ...
# 1996  1.287092e-07  1.373082e-07  1.127619e-09  1.327108e-09  3.278008e-07
# 1997  1.283121e-07  1.368441e-07  1.124972e-09  1.324428e-09  3.269647e-07
# 1998  1.279167e-07  1.363822e-07  1.122160e-09  1.321542e-09  3.261339e-07
# 1999  1.275228e-07  1.359223e-07  1.119177e-09  1.318440e-09  3.253084e-07
# 2000  1.271303e-07  1.354643e-07  1.116017e-09  1.315113e-09  3.244883e-07
#
#         J_4p1/2(2)    J_4p3/2(4)    J_5s1/2(1)  J_total_Rb_relativistic
# 0     8.560914e-01  1.755739e+00  2.421657e+00                 8.883726
# 1     8.560712e-01  1.755693e+00  2.288720e+00                 8.745295
# 2     8.558928e-01  1.755286e+00  1.934794e+00                 8.374646
# 3     8.552189e-01  1.753751e+00  1.468872e+00                 7.880099
# 4     8.535376e-01  1.749931e+00  1.007968e+00                 7.377686
# ...            ...           ...           ...                      ...
# 1996  1.352720e-08  1.470768e-08  8.360590e-09                 0.000131
# 1997  1.349345e-08  1.467083e-08  8.338325e-09                 0.000131
# 1998  1.345998e-08  1.463436e-08  8.316320e-09                 0.000130
# 1999  1.342669e-08  1.459811e-08  8.294624e-09                 0.000130
# 2000  1.339348e-08  1.456195e-08  8.273256e-09                 0.000130
#
# [2001 rows x 15 columns]
