# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.special import spherical_jn
from scipy.integrate import cumulative_trapezoid

csv_file = "/root/geant4/fac/Cd_all_wavefunctions.csv"
df = pd.read_csv(csv_file)
df = df.dropna(subset=["r", "P", "Q"])

p = np.arange(0.0, 300.0 + 0.05, 0.05)
Qgrid = np.arange(0.0, 100.0 + 0.05, 0.05)

print(df["Orbital"].unique())


def get_orbital(df, name, print_values=True):
    d = df[df["Orbital"] == name].copy()
    d = d.sort_values("r")

    r_raw = d["r"].to_numpy()
    P_raw = d["P"].to_numpy()
    Q_raw = d["Q"].to_numpy()

    if print_values:
        print("\n======================")
        print(name)
        print("======================")
        print(d[["r", "P", "Q"]].head(8))
        print(d[["r", "P", "Q"]].tail(8))

    raw_norm = np.trapezoid(P_raw**2 + Q_raw**2, r_raw)
    print(name, "raw radial norm ∫(P²+Q²)dr =", raw_norm)

    # normalize raw FAC P,Q
    P_raw = P_raw / np.sqrt(raw_norm)
    Q_raw = Q_raw / np.sqrt(raw_norm)

    # interpolate to finer r grid
    r = np.linspace(r_raw.min(), r_raw.max(), 5000)
    P = np.interp(r, r_raw, P_raw)
    Qs = np.interp(r, r_raw, Q_raw)

    fine_norm = np.trapezoid(P**2 + Qs**2, r)
    P = P / np.sqrt(fine_norm)
    Qs = Qs / np.sqrt(fine_norm)

    print(name, "fine radial norm after interpolation =", np.trapezoid(P**2 + Qs**2, r))

    return r, P, Qs
   # return r_raw, P_raw, Q_raw

def chi_transform(p_grid, r, radial, l):
    chi = []

    for pp in p_grid:
        jl = spherical_jn(l, pp*r)

        # FAC P = rG, Q = rF
        # chi = sqrt(2/pi) int P(r) j_l(pr) r dr
        val = np.sqrt(2/np.pi) * np.trapezoid(radial * jl * r, r)

        chi.append(val)

    return np.array(chi)


def calculate_J(p_grid, chiG, chiF, Qgrid):
    integrand = (chiG**2 + chiF**2) * p_grid

    rev = cumulative_trapezoid(
        integrand[::-1],
        p_grid[::-1],
        initial=0
    )

    J_p = -0.5 * rev[::-1]
    J_Q = np.interp(Qgrid, p_grid, J_p)

    return J_Q


def one_orbital_J(df, name, l_large, l_small):
    r, P, Qs = get_orbital(df, name)

    chiG = chi_transform(p, r, P, l_large)
    chiF = chi_transform(p, r, Qs, l_small)

    I = (chiG**2 + chiF**2) * p**2
    print(name, "momentum norm ∫I(p)dp =", np.trapezoid(I, p))

    J = calculate_J(p, chiG, chiF, Qgrid)
    print(name, "Compton check 2∫J(Q)dQ =", 2*np.trapezoid(J, Qgrid))

    return J


# =====================================================
# Relativistic orbitals
# large component l = orbital l
# small component l' is decided by j
# =====================================================

J_1s12 = one_orbital_J(df, "Cd_1s12", 0, 1)

J_2s12 = one_orbital_J(df, "Cd_2s12", 0, 1)
J_2p12 = one_orbital_J(df, "Cd_2p12", 1, 0)
J_2p32 = one_orbital_J(df, "Cd_2p32", 1, 2)

J_3s12 = one_orbital_J(df, "Cd_3s12", 0, 1)
J_3p12 = one_orbital_J(df, "Cd_3p12", 1, 0)
J_3p32 = one_orbital_J(df, "Cd_3p32", 1, 2)

J_3d32 = one_orbital_J(df, "Cd_3d32", 2, 1)
J_3d52 = one_orbital_J(df, "Cd_3d52", 2, 3)

J_4s12 = one_orbital_J(df, "Cd_4s12", 0, 1)
J_4p12 = one_orbital_J(df, "Cd_4p12", 1, 0)
J_4p32 = one_orbital_J(df, "Cd_4p32", 1, 2)
J_4d32 = one_orbital_J(df, "Cd_4d32", 2, 1)
J_4d52 = one_orbital_J(df, "Cd_4d52", 2, 3)

J_5s12 = one_orbital_J(df, "Cd_5s12", 0, 1)

J_total_Cd_rel = (
    2*J_1s12
    + 2*J_2s12
    + 2*J_2p12 + 4*J_2p32
    + 2*J_3s12
    + 2*J_3p12 + 4*J_3p32
    + 4*J_3d32 + 6*J_3d52
    + 2*J_4s12
    + 2*J_4p12 + 4*J_4p32
    + 4*J_4d32 + 6*J_4d52
    + 2*J_5s12
    )

print("\nTotal Pdcheck 2∫Jtotal dQ =", 2*np.trapezoid(J_total_Cd_rel, Qgrid))
print("Expected close to 48")


table = pd.DataFrame({
    "Q": Qgrid,
    "J_1s1/2(2)": J_1s12,
    "J_2s1/2(2)": J_2s12,
    "J_2p1/2(2)": J_2p12,
    "J_2p3/2(4)": J_2p32,
    "J_3s1/2(2)": J_3s12,
    "J_3p1/2(2)": J_3p12,
    "J_3p3/2(4)": J_3p32,
    "J_3d3/2(4)": J_3d32,
    "J_3d5/2(6)": J_3d52,
    "J_4s1/2(2)": J_4s12,
    "J_4p1/2(2)": J_4p12,
    "J_4p3/2(4)": J_4p32,
    "J_4d3/2(4)": J_4d32,
    "J_4d5/2(4)": J_4d52,
    "J_5s1/2(1)": J_5s12,
    "J_total_Cd_relativistic": J_total_Cd_rel
})

table.to_csv("Cd_relativistic_Compton_profile.csv", index=False)
print(table)


plt.figure(figsize=(8,6))
plt.plot(Qgrid, 2*J_1s12, label="1s(2)")
plt.plot(Qgrid, 2*J_2s12, label="2s(2)")
plt.plot(Qgrid, 2*J_2p12 + 4*J_2p32, label="2p(6)")
plt.plot(Qgrid, 2*J_3s12, label="3s(2)")
plt.plot(Qgrid, 2*J_3p12 + 4*J_3p32, label="3p(6)")
plt.plot(Qgrid, 4*J_3d32 + 6*J_3d52, label="3d(10)")
plt.plot(Qgrid, 2*J_4s12, label="4s(2)")
plt.plot(Qgrid, 2*J_4p12 + 4*J_4p32, label="4p(6)")
plt.plot(Qgrid, 4*J_4d32 + 4*J_4d52, label="4d(10)")
plt.plot(Qgrid, 1*J_5s12, label="5s(2)")
plt.plot(Qgrid, J_total_Cd_rel, label="Cd total relativistic", linewidth=2)

plt.xlabel("Q (a.u.)")
plt.ylabel("J(Q)")
plt.title("Relativistic Cadmium Compton Profile")
plt.yscale("log")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# ['Cd_1s12' 'Cd_2p12' 'Cd_2p32' 'Cd_2s12' 'Cd_3d32' 'Cd_3d52' 'Cd_3p12'
#  'Cd_3p32' 'Cd_3s12' 'Cd_4d32' 'Cd_4d52' 'Cd_4p12' 'Cd_4p32' 'Cd_4s12'
#  'Cd_5s12']
#
# ======================
# Cd_1s12
# ======================
#               r         P             Q
# 0  2.083333e-08  0.000019 -6.597422e-10
# 1  2.284584e-08  0.000021 -7.932964e-10
# 2  2.505272e-08  0.000023 -9.538985e-10
# 3  2.747278e-08  0.000026 -1.147029e-09
# 4  3.012661e-08  0.000028 -1.379274e-09
# 5  3.303674e-08  0.000031 -1.658551e-09
# 6  3.622792e-08  0.000034 -1.994381e-09
# 7  3.972735e-08  0.000037 -2.398223e-09
#             r             P             Q
# 198  0.444937  3.088113e-07 -5.108303e-08
# 199  0.469716  1.061717e-07 -1.743557e-08
# 200  0.495575  3.477623e-08 -5.661915e-09
# 201  0.522544  1.083718e-08 -1.746324e-09
# 202  0.550654  3.208488e-09 -5.106735e-10
# 203  0.579933  9.011798e-10 -1.413146e-10
# 204  0.610411  2.397789e-10 -5.395222e-11
# 205  0.642118  6.034503e-11  3.456230e-11
# Cd_1s12 raw radial norm ∫(P²+Q²)dr = 1.0007944441808294
# Cd_1s12 fine radial norm after interpolation = 0.9999999999999999
# Cd_1s12 momentum norm ∫I(p)dp = 0.9990293949947636
# Cd_1s12 Compton check 2∫J(Q)dQ = 0.9899090265932631
#
# ======================
# Cd_2s12
# ======================
#                 r         P             Q
# 662  2.083333e-08  0.000007 -2.245208e-10
# 663  2.284584e-08  0.000007 -2.699714e-10
# 664  2.505272e-08  0.000008 -3.246269e-10
# 665  2.747278e-08  0.000009 -3.903523e-10
# 666  3.012661e-08  0.000010 -4.693892e-10
# 667  3.303674e-08  0.000011 -5.644315e-10
# 668  3.622792e-08  0.000012 -6.787199e-10
# 669  3.972735e-08  0.000013 -8.161539e-10
#             r             P             Q
# 882  1.284980 -5.280106e-08  3.359955e-09
# 883  1.340275 -2.074738e-08  1.315490e-09
# 884  1.397280 -7.912465e-09  4.996911e-10
# 885  1.456022 -2.927533e-09  1.840645e-10
# 886  1.516526 -1.050377e-09  6.571771e-11
# 887  1.578818 -3.653029e-10  2.273129e-11
# 888  1.642924 -1.230933e-10  8.955422e-12
# 889  1.708869 -4.016958e-11 -9.327798e-13
# Cd_2s12 raw radial norm ∫(P²+Q²)dr = 1.0004618447968288
# Cd_2s12 fine radial norm after interpolation = 1.0
# Cd_2s12 momentum norm ∫I(p)dp = 0.9998811095217177
# Cd_2s12 Compton check 2∫J(Q)dQ = 0.9985776732089594
#
# ======================
# Cd_2p12
# ======================
#                 r             P             Q
# 206  2.083333e-08  3.524999e-11  9.834673e-07
# 207  2.284584e-08  4.236780e-11  1.078483e-06
# 208  2.505272e-08  5.092899e-11  1.182664e-06
# 209  2.747278e-08  6.122573e-11  1.296900e-06
# 210  3.012661e-08  7.360935e-11  1.422178e-06
# 211  3.303674e-08  8.850223e-11  1.559567e-06
# 212  3.622792e-08  1.064124e-10  1.710216e-06
# 213  3.972735e-08  1.279507e-10  1.875403e-06
#             r             P             Q
# 426  1.284980  6.358002e-08 -3.562301e-09
# 427  1.340275  2.576259e-08 -1.444064e-09
# 428  1.397280  1.014298e-08 -5.684717e-10
# 429  1.456022  3.878543e-09 -2.172242e-10
# 430  1.516526  1.439854e-09 -8.053610e-11
# 431  1.578818  5.187207e-10 -2.895729e-11
# 432  1.642924  1.812722e-10 -1.173828e-11
# 433  1.708869  6.142247e-11  7.583585e-13
# Cd_2p12 raw radial norm ∫(P²+Q²)dr = 1.0004978965345084
# Cd_2p12 fine radial norm after interpolation = 1.0
# Cd_2p12 momentum norm ∫I(p)dp = 0.9999959798356459
# Cd_2p12 Compton check 2∫J(Q)dQ = 0.999900481571879
#
# ======================
# Cd_2p32
# ======================
#                 r             P             Q
# 434  2.083333e-08  1.489430e-12 -3.032002e-17
# 435  2.284584e-08  1.790181e-12 -3.997422e-17
# 436  2.505272e-08  2.151920e-12 -5.269769e-17
# 437  2.747278e-08  2.586992e-12 -6.947004e-17
# 438  3.012661e-08  3.110241e-12 -9.158263e-17
# 439  3.303674e-08  3.739516e-12 -1.207376e-16
# 440  3.622792e-08  4.496280e-12 -1.591797e-16
# 441  3.972735e-08  5.406350e-12 -2.098697e-16
#             r             P             Q
# 654  1.284980  1.118825e-07 -7.061521e-09
# 655  1.340275  4.645258e-08 -2.917678e-09
# 656  1.397280  1.875390e-08 -1.172007e-09
# 657  1.456022  7.359267e-09 -4.574972e-10
# 658  1.516526  2.805854e-09 -1.734687e-10
# 659  1.578818  1.038983e-09 -6.386078e-11
# 660  1.642924  3.734992e-10 -2.559432e-11
# 661  1.708869  1.302963e-10 -9.370397e-13
# Cd_2p32 raw radial norm ∫(P²+Q²)dr = 1.0004865290602114
# Cd_2p32 fine radial norm after interpolation = 1.0
# Cd_2p32 momentum norm ∫I(p)dp = 0.9999994180703372
# Cd_2p32 Compton check 2∫J(Q)dQ = 0.9999602301099135
#
# ======================
# Cd_3s12
# ======================
#                  r         P             Q
# 1918  2.083333e-08  0.000003 -9.820292e-11
# 1919  2.284584e-08  0.000003 -1.180825e-10
# 1920  2.505272e-08  0.000003 -1.419882e-10
# 1921  2.747278e-08  0.000004 -1.707358e-10
# 1922  3.012661e-08  0.000004 -2.053057e-10
# 1923  3.303674e-08  0.000005 -2.468761e-10
# 1924  3.622792e-08  0.000005 -2.968646e-10
# 1925  3.972735e-08  0.000006 -3.569767e-10
#              r             P             Q
# 2160  2.934851  5.151850e-08 -1.434206e-09
# 2161  3.033386  2.501771e-08 -6.952037e-10
# 2162  3.134139  1.194966e-08 -3.314535e-10
# 2163  3.237132  5.613430e-09 -1.554112e-10
# 2164  3.342383  2.593021e-09 -7.165220e-11
# 2165  3.449912  1.177687e-09 -3.247903e-11
# 2166  3.559737  5.258239e-10 -1.507906e-11
# 2167  3.671876  2.307696e-10 -4.852918e-12
# Cd_3s12 raw radial norm ∫(P²+Q²)dr = 1.0002618189157884
# Cd_3s12 fine radial norm after interpolation = 0.9999999999999998
# Cd_3s12 momentum norm ∫I(p)dp = 0.9999767218651799
# Cd_3s12 Compton check 2∫J(Q)dQ = 0.9997191723358346
#
# ======================
# Cd_3p12
# ======================
#                  r             P             Q
# 1410  2.083333e-08  1.599570e-11  4.462056e-07
# 1411  2.284584e-08  1.922561e-11  4.893148e-07
# 1412  2.505272e-08  2.311050e-11  5.365824e-07
# 1147  4.654450  2.378617e-10 -4.323399e-12
# 1148  4.788209  1.147458e-10 -2.154818e-12
# 1149  4.924453  5.460958e-11 -8.358462e-13
# Cd_3d32 raw radial norm ∫(P²+Q²)dr = 1.000272911985805
# Cd_3d32 fine radial norm after interpolation = 1.0000000000000002
# Cd_3d32 momentum norm ∫I(p)dp = 0.999999946884881
# Cd_3d32 Compton check 2∫J(Q)dQ = 0.9999998457024684
#
# ======================
# Cd_3d52
# ======================
#                  r             P             Q
# 1150  2.083333e-08  3.239630e-20 -4.719819e-25
# 1151  2.284584e-08  4.261109e-20 -6.819879e-25
# 1152  2.505272e-08  5.609968e-20 -9.847991e-25
# 1153  2.747278e-08  7.390227e-20 -1.422133e-24
# 1154  3.012661e-08  9.739104e-20 -2.054220e-24
# 1155  3.303674e-08  1.283757e-19 -2.968076e-24
# 1156  3.622792e-08  1.692432e-19 -4.289487e-24
# 1157  3.972735e-08  2.231413e-19 -6.200344e-24
#              r             P             Q
# 1402  4.022364  8.974335e-09 -2.006316e-10
# 1403  4.143941  4.653091e-09 -1.036092e-10
# 1404  4.267922  2.381542e-09 -5.282258e-11
# 1405  4.394323  1.203124e-09 -2.658387e-11
# 1406  4.523160  5.998689e-10 -1.320534e-11
# 1407  4.654450  2.951583e-10 -6.473944e-12
# 1408  4.788209  1.433065e-10 -3.206679e-12
# 1409  4.924453  6.865131e-11 -1.314692e-12
# Cd_3d52 raw radial norm ∫(P²+Q²)dr = 1.000270955810771
# Cd_3d52 fine radial norm after interpolation = 0.9999999999999996
# Cd_3d52 momentum norm ∫I(p)dp = 0.9999999471177695
# Cd_3d52 Compton check 2∫J(Q)dQ = 0.9999998801830539
#
# ======================
# Cd_4s12
# ======================
#                  r         P             Q
# 3444  2.083333e-08  0.000001 -4.348895e-11
# 3445  2.284584e-08  0.000001 -5.229259e-11
# 3446  2.505272e-08  0.000002 -6.287919e-11
# 3447  2.747278e-08  0.000002 -7.560997e-11
# 3448  3.012661e-08  0.000002 -9.091916e-11
# 3449  3.303674e-08  0.000002 -1.093286e-10
# 3450  3.622792e-08  0.000002 -1.314658e-10
# 3451  3.972735e-08  0.000002 -1.580864e-10
#              r             P             Q
# 3724  8.385178 -2.952206e-09  3.121041e-11
# 3725  8.579638 -1.717944e-09  1.814837e-11
# 3726  8.776887 -9.917871e-10  1.046955e-11
# 3727  8.976936 -5.680178e-10  5.991792e-12
# 3728  9.179794 -3.227204e-10  3.401812e-12
# 3729  9.385474 -1.818859e-10  1.915912e-12
# 3730  9.593986 -1.016874e-10  1.081017e-12
# 3731  9.805338 -5.639211e-11  5.680220e-13
# Cd_4s12 raw radial norm ∫(P²+Q²)dr = 1.0001345096749787
# Cd_4s12 fine radial norm after interpolation = 1.0
# Cd_4s12 momentum norm ∫I(p)dp = 0.9999954082172882
# Cd_4s12 Compton check 2∫J(Q)dQ = 0.9999444585975842
#
# ======================
# Cd_4p12
# ======================
#                  r             P             Q
# 2850  2.083333e-08  6.742697e-12  1.880844e-07
# 2851  2.284584e-08  8.104208e-12  2.062558e-07
# 2852  2.505272e-08  9.741812e-12  2.261800e-07
# 2853  2.747278e-08  1.171140e-11  2.480273e-07
# 2854  3.012661e-08  1.408016e-11  2.719862e-07
# 2855  3.303674e-08  1.692890e-11  2.982613e-07
# 2856  3.622792e-08  2.035480e-11  3.270723e-07
# 2857  3.972735e-08  2.447471e-11  3.586637e-07
#               r             P             Q
# 3138  10.019543  2.470439e-09 -1.970600e-11
# 3139  10.236610  1.502893e-09 -1.200254e-11
# 3140  10.456548  9.081506e-10 -7.261147e-12
# 3141  10.679367  5.450715e-10 -4.363002e-12
# 3142  10.905078  3.249415e-10 -2.603781e-12
# 3143  11.133689  1.923993e-10 -1.543310e-12
# 3144  11.365209  1.131459e-10 -9.150252e-13
# 3145  11.599648  6.608487e-11 -5.158429e-13
# Cd_4p12 raw radial norm ∫(P²+Q²)dr = 1.0001287994858572
# Cd_4p12 fine radial norm after interpolation = 1.0
# Cd_4p12 momentum norm ∫I(p)dp = 0.9999997780004722
# Cd_4p12 Compton check 2∫J(Q)dQ = 0.9999960599719412
#
# ======================
# Cd_4p32
# ======================
#                  r             P             Q
# 3146  2.083333e-08  2.854042e-13 -5.806940e-18
# 3147  2.284584e-08  3.430341e-13 -7.655930e-18
# 3148  2.505272e-08  4.123504e-13 -1.009275e-17
# 3149  2.747278e-08  4.957188e-13 -1.330502e-17
# 3150  3.012661e-08  5.959837e-13 -1.754006e-17
# 3151  3.303674e-08  7.165651e-13 -2.312387e-17
# 3152  3.622792e-08  8.615761e-13 -3.048636e-17
# 3153  3.972735e-08  1.035963e-12 -4.019460e-17
#               r             P             Q
# 3436  10.456548  2.388121e-09 -2.074711e-11
# 3437  10.679367  1.465002e-09 -1.270888e-11
# 3438  10.905078  8.928874e-10 -7.734794e-12
# 3439  11.133689  5.406581e-10 -4.677055e-12
# 3440  11.365209  3.252424e-10 -2.809756e-12
# 3441  11.599648  1.943753e-10 -1.676979e-12
# 3442  11.837014  1.154027e-10 -1.000230e-12
# 3443  12.077317  6.806485e-11 -5.719973e-13
# Cd_4p32 raw radial norm ∫(P²+Q²)dr = 1.0001252610511095
# Cd_4p32 fine radial norm after interpolation = 0.9999999999999998
# Cd_4p32 momentum norm ∫I(p)dp = 0.9999999042449785
# Cd_4p32 Compton check 2∫J(Q)dQ = 0.9999983314936788
#
# ======================
# Cd_4d32
# ======================
#                  r             P             Q
# 2168  2.083333e-08  2.336305e-19  1.080900e-14
# 2169  2.284584e-08  3.072960e-19  1.299788e-14
# 2170  2.505272e-08  4.045708e-19  1.563053e-14
# 2171  2.747278e-08  5.329567e-19  1.879605e-14
# 2172  3.012661e-08  7.023492e-19  2.260276e-14
# 2173  3.303674e-08  9.257996e-19  2.718058e-14
# 2174  3.622792e-08  1.220521e-18  3.268533e-14
# 2175  3.972735e-08  1.609214e-18  3.930458e-14
#               r             P             Q
# 2500  22.398521 -1.239407e-09  4.058054e-12
# 2501  22.749523 -8.764378e-10  2.875561e-12
# 2502  23.103716 -6.177094e-10  2.030781e-12
# 2503  23.461106 -4.339113e-10  1.429346e-12
# 2504  23.821698 -3.037869e-10  1.002636e-12
# 2505  24.185498 -2.119757e-10  7.009385e-13
# 2506  24.552511 -1.474177e-10  4.890816e-13
# 2507  24.922740 -1.021781e-10  3.374941e-13
# Cd_4d32 raw radial norm ∫(P²+Q²)dr = 1.0001024010477388
# Cd_4d32 fine radial norm after interpolation = 1.0
# Cd_4d32 momentum norm ∫I(p)dp = 0.9999999887217068
# Cd_4d32 Compton check 2∫J(Q)dQ = 0.9999999578865677
#
# ======================
# Cd_4d52
# ======================
#                  r             P             Q
# 2508  2.083333e-08  1.129067e-20 -1.642892e-25
# 2509  2.284584e-08  1.485070e-20 -2.373889e-25
# 2510  2.505272e-08  1.955170e-20 -3.427926e-25
# 2511  2.747278e-08  2.575622e-20 -4.950214e-25
# 2512  3.012661e-08  3.394246e-20 -7.150408e-25
# 2513  3.303674e-08  4.474116e-20 -1.033139e-24
# 2514  3.622792e-08  5.898417e-20 -1.493101e-24
# 2515  3.972735e-08  7.776859e-20 -2.158239e-24
#               r             P             Q
# 2842  23.103716 -1.142761e-09  4.545017e-12
# 2843  23.461106 -8.106517e-10  3.219705e-12
# 2844  23.821698 -5.731926e-10  2.273509e-12
# 2845  24.185498 -4.039727e-10  1.600203e-12
# 2846  24.552511 -2.837831e-10  1.122660e-12
# 2847  24.922740 -1.987017e-10  7.850797e-13
# 2848  25.296193 -1.386741e-10  5.478549e-13
# 2849  25.672873 -9.646405e-11  3.787939e-13
# Cd_4d52 raw radial norm ∫(P²+Q²)dr = 1.000101024866565
# Cd_4d52 fine radial norm after interpolation = 1.0
# Cd_4d52 momentum norm ∫I(p)dp = 0.9999999865680166
# Cd_4d52 Compton check 2∫J(Q)dQ = 0.9999999597185151
#
# ======================
# Cd_5s12
# ======================
#                  r             P             Q
# 3732  2.083333e-08  3.310237e-07 -1.122343e-11
# 3733  2.284584e-08  3.629945e-07 -1.349544e-11
# 3734  2.505272e-08  3.980533e-07 -1.622758e-11
# 3735  2.747278e-08  4.364986e-07 -1.951308e-11
# 3736  3.012661e-08  4.786574e-07 -2.346401e-11
# 3737  3.303674e-08  5.248881e-07 -2.821502e-11
# 3738  3.622792e-08  5.755838e-07 -3.392811e-11
# 3739  3.972735e-08  6.311761e-07 -4.079821e-11
#               r             P             Q
# 4094  34.336876  1.338815e-09 -3.575954e-12
# 4095  34.785702  9.763885e-10 -2.608385e-12
# 4096  35.237854  7.102461e-10 -1.897727e-12
# 4097  35.693337  5.153214e-10 -1.377138e-12
# 4098  36.152153  3.729323e-10 -9.967865e-13
# 4099  36.614308  2.691929e-10 -7.196261e-13
# 4100  37.079803  1.938109e-10 -5.186381e-13
# 4101  37.548644  1.391787e-10 -3.711857e-13
# Cd_5s12 raw radial norm ∫(P²+Q²)dr = 1.000041424486553
# Cd_5s12 fine radial norm after interpolation = 1.0
# Cd_5s12 momentum norm ∫I(p)dp = 0.9999998352039614
# Cd_5s12 Compton check 2∫J(Q)dQ = 0.999996537341566
#
# Total Pdcheck 2∫Jtotal dQ = 47.97584094828241
# Expected close to 48
