# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.special import spherical_jn
from scipy.integrate import cumulative_trapezoid

csv_file = "/root/geant4/fac/Sn_all_wavefunctions.csv"
df = pd.read_csv(csv_file)
df = df.dropna(subset=["r", "P", "Q"])

p = np.arange(0.0, 300.0 + 0.05, 0.05)
Qgrid = np.arange(0.0, 100.0 + 0.05, 0.05)

print(df["Orbital"].unique())


def get_orbital(df, name, print_values=True):
    d = df[df["Orbital"] == name].copy()
    d = d.sort_values("r")

    r_raw = d["r"].to_numpy()
    P_raw = d["P"].to_numpy()
    Q_raw = d["Q"].to_numpy()

    if print_values:
        print("\n======================")
        print(name)
        print("======================")
        print(d[["r", "P", "Q"]].head(8))
        print(d[["r", "P", "Q"]].tail(8))

    raw_norm = np.trapezoid(P_raw**2 + Q_raw**2, r_raw)
    print(name, "raw radial norm ∫(P²+Q²)dr =", raw_norm)

    # normalize raw FAC P,Q
    P_raw = P_raw / np.sqrt(raw_norm)
    Q_raw = Q_raw / np.sqrt(raw_norm)

    # interpolate to finer r grid
    r = np.linspace(r_raw.min(), r_raw.max(), 5000)
    P = np.interp(r, r_raw, P_raw)
    Qs = np.interp(r, r_raw, Q_raw)

    fine_norm = np.trapezoid(P**2 + Qs**2, r)
    P = P / np.sqrt(fine_norm)
    Qs = Qs / np.sqrt(fine_norm)

    print(name, "fine radial norm after interpolation =", np.trapezoid(P**2 + Qs**2, r))

    return r, P, Qs
   # return r_raw, P_raw, Q_raw

def chi_transform(p_grid, r, radial, l):
    chi = []

    for pp in p_grid:
        jl = spherical_jn(l, pp*r)

        # FAC P = rG, Q = rF
        # chi = sqrt(2/pi) int P(r) j_l(pr) r dr
        val = np.sqrt(2/np.pi) * np.trapezoid(radial * jl * r, r)

        chi.append(val)

    return np.array(chi)


def calculate_J(p_grid, chiG, chiF, Qgrid):
    integrand = (chiG**2 + chiF**2) * p_grid

    rev = cumulative_trapezoid(
        integrand[::-1],
        p_grid[::-1],
        initial=0
    )

    J_p = -0.5 * rev[::-1]
    J_Q = np.interp(Qgrid, p_grid, J_p)

    return J_Q


def one_orbital_J(df, name, l_large, l_small):
    r, P, Qs = get_orbital(df, name)

    chiG = chi_transform(p, r, P, l_large)
    chiF = chi_transform(p, r, Qs, l_small)

    I = (chiG**2 + chiF**2) * p**2
    print(name, "momentum norm ∫I(p)dp =", np.trapezoid(I, p))

    J = calculate_J(p, chiG, chiF, Qgrid)
    print(name, "Compton check 2∫J(Q)dQ =", 2*np.trapezoid(J, Qgrid))

    return J


# =====================================================
# Relativistic orbitals
# large component l = orbital l
# small component l' is decided by j
# =====================================================

J_1s12 = one_orbital_J(df, "Sn_1s12", 0, 1)

J_2s12 = one_orbital_J(df, "Sn_2s12", 0, 1)
J_2p12 = one_orbital_J(df, "Sn_2p12", 1, 0)
J_2p32 = one_orbital_J(df, "Sn_2p32", 1, 2)

J_3s12 = one_orbital_J(df, "Sn_3s12", 0, 1)
J_3p12 = one_orbital_J(df, "Sn_3p12", 1, 0)
J_3p32 = one_orbital_J(df, "Sn_3p32", 1, 2)

J_3d32 = one_orbital_J(df, "Sn_3d32", 2, 1)
J_3d52 = one_orbital_J(df, "Sn_3d52", 2, 3)

J_4s12 = one_orbital_J(df, "Sn_4s12", 0, 1)
J_4p12 = one_orbital_J(df, "Sn_4p12", 1, 0)
J_4p32 = one_orbital_J(df, "Sn_4p32", 1, 2)
J_4d32 = one_orbital_J(df, "Sn_4d32", 2, 1)
J_4d52 = one_orbital_J(df, "Sn_4d52", 2, 3)

J_5s12 = one_orbital_J(df, "Sn_5s12", 0, 1)
J_5p12 = one_orbital_J(df, "Sn_5p12", 1, 0)

J_total_Sn_rel = (
    2*J_1s12
    + 2*J_2s12
    + 2*J_2p12 + 4*J_2p32
    + 2*J_3s12
    + 2*J_3p12 + 4*J_3p32
    + 4*J_3d32 + 6*J_3d52
    + 2*J_4s12
    + 2*J_4p12 + 4*J_4p32
    + 4*J_4d32 + 6*J_4d52
    + 2*J_5s12
    + 2*J_5p12
    )

print("\nTotal Pdcheck 2∫Jtotal dQ =", 2*np.trapezoid(J_total_Sn_rel, Qgrid))
print("Expected close to 50")


table = pd.DataFrame({
    "Q": Qgrid,
    "J_1s1/2(2)": J_1s12,
    "J_2s1/2(2)": J_2s12,
    "J_2p1/2(2)": J_2p12,
    "J_2p3/2(4)": J_2p32,
    "J_3s1/2(2)": J_3s12,
    "J_3p1/2(2)": J_3p12,
    "J_3p3/2(4)": J_3p32,
    "J_3d3/2(4)": J_3d32,
    "J_3d5/2(6)": J_3d52,
    "J_4s1/2(2)": J_4s12,
    "J_4p1/2(2)": J_4p12,
    "J_4p3/2(4)": J_4p32,
    "J_4d3/2(4)": J_4d32,
    "J_4d5/2(4)": J_4d52,
    "J_5s1/2(2)": J_5s12,
    "J_5p1/2(2)": J_5p12,
    "J_total_Sn_relativistic": J_total_Sn_rel
})

table.to_csv("Sn_relativistic_Compton_profile.csv", index=False)
print(table)


plt.figure(figsize=(8,6))
plt.plot(Qgrid, 2*J_1s12, label="1s(2)")
plt.plot(Qgrid, 2*J_2s12, label="2s(2)")
plt.plot(Qgrid, 2*J_2p12 + 4*J_2p32, label="2p(6)")
plt.plot(Qgrid, 2*J_3s12, label="3s(2)")
plt.plot(Qgrid, 2*J_3p12 + 4*J_3p32, label="3p(6)")
plt.plot(Qgrid, 4*J_3d32 + 6*J_3d52, label="3d(10)")
plt.plot(Qgrid, 2*J_4s12, label="4s(2)")
plt.plot(Qgrid, 2*J_4p12 + 4*J_4p32, label="4p(6)")
plt.plot(Qgrid, 4*J_4d32 + 4*J_4d52, label="4d(10)")
plt.plot(Qgrid, 2*J_5s12, label="5s(2)")
plt.plot(Qgrid, 2*J_5p12, label="5p(2)")
plt.plot(Qgrid, J_total_Sn_rel, label="Sn total relativistic", linewidth=2)

plt.xlabel("Q (a.u.)")
plt.ylabel("J(Q)")
plt.title("Relativistic Tin Compton Profile")
plt.yscale("log")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# ['Sn_1s12' 'Sn_2p12' 'Sn_2p32' 'Sn_2s12' 'Sn_3d32' 'Sn_3d52' 'Sn_3p12'
#  'Sn_3p32' 'Sn_3s12' 'Sn_4d32' 'Sn_4d52' 'Sn_4p12' 'Sn_4p32' 'Sn_4s12'
#  'Sn_5p12' 'Sn_5s12']
#
# ======================
# Sn_1s12
# ======================
#               r         P             Q
# 0  2.000000e-08  0.000020 -6.827339e-10
# 1  2.193213e-08  0.000022 -8.209488e-10
# 2  2.405086e-08  0.000025 -9.871573e-10
# 3  2.637428e-08  0.000027 -1.187032e-09
# 4  2.892210e-08  0.000030 -1.427385e-09
# 5  3.171605e-08  0.000032 -1.716420e-09
# 6  3.477983e-08  0.000036 -2.063988e-09
# 7  3.813958e-08  0.000039 -2.481949e-09
#             r             P             Q
# 198  0.434525  2.165686e-07 -3.736411e-08
# 199  0.458845  7.246869e-08 -1.240275e-08
# 200  0.484233  2.306607e-08 -3.909907e-09
# 201  0.510719  6.973235e-09 -1.168448e-09
# 202  0.538331  1.999349e-09 -3.303719e-10
# 203  0.567101  5.428453e-10 -8.819322e-11
# 204  0.597057  1.393535e-10 -3.417917e-11
# 205  0.628228  3.376866e-11  2.565628e-11
# Sn_1s12 raw radial norm ∫(P²+Q²)dr = 1.0008038704204345
# Sn_1s12 fine radial norm after interpolation = 1.0
# Sn_1s12 momentum norm ∫I(p)dp = 0.9987846246164135
# Sn_1s12 Compton check 2∫J(Q)dQ = 0.987869499444129
#
# ======================
# Sn_2s12
# ======================
#                 r         P             Q
# 660  2.000000e-08  0.000007 -2.341780e-10
# 661  2.193213e-08  0.000008 -2.815858e-10
# 662  2.405086e-08  0.000008 -3.385955e-10
# 663  2.637428e-08  0.000009 -4.071525e-10
# 664  2.892210e-08  0.000010 -4.895939e-10
# 665  3.171605e-08  0.000011 -5.887330e-10
# 666  3.477983e-08  0.000012 -7.079490e-10
# 667  3.813958e-08  0.000013 -8.513100e-10
#             r             P             Q
# 878  1.157429 -1.708437e-07  1.148932e-08
# 879  1.208676 -6.874431e-08  4.607773e-09
# 880  1.261569 -2.683433e-08  1.792008e-09
# 881  1.316133 -1.015689e-08  6.754953e-10
# 882  1.372396 -3.726026e-09  2.466696e-10
# 883  1.430384 -1.324169e-09  8.721515e-11
# 884  1.490124 -4.556688e-10  3.448364e-11
# 885  1.551641 -1.517603e-10 -1.824818e-12
# Sn_2s12 raw radial norm ∫(P²+Q²)dr = 1.0004723315580117
# Sn_2s12 fine radial norm after interpolation = 1.0
# Sn_2s12 momentum norm ∫I(p)dp = 0.9998483614383796
# Sn_2s12 Compton check 2∫J(Q)dQ = 0.998242238450073
#
# ======================
# Sn_2p12
# ======================
#                 r             P         Q
# 206  2.000000e-08  3.845661e-11  0.000001
# 207  2.193213e-08  4.622237e-11  0.000001
# 208  2.405086e-08  5.556300e-11  0.000001
# 209  2.637428e-08  6.679730e-11  0.000001
# 210  2.892210e-08  8.030857e-11  0.000002
# 211  3.171605e-08  9.655783e-11  0.000002
# 212  3.477983e-08  1.160994e-10  0.000002
# 213  3.813958e-08  1.395998e-10  0.000002
#             r             P             Q
# 424  1.157429  1.925891e-07 -1.136108e-08
# 425  1.208676  7.972858e-08 -4.708031e-09
# 426  1.261569  3.205375e-08 -1.893616e-09
# 427  1.316133  1.250930e-08 -7.388828e-10
# 428  1.372396  4.736773e-09 -2.795657e-10
# 429  1.430384  1.739531e-09 -1.025194e-10
# 430  1.490124  6.192782e-10 -4.174838e-11
# 431  1.551641  2.136220e-10  9.061719e-13
# Sn_2p12 raw radial norm ∫(P²+Q²)dr = 1.0005090412055795
# Sn_2p12 fine radial norm after interpolation = 1.0000000000000002
# Sn_2p12 momentum norm ∫I(p)dp = 0.9999943516757409
# Sn_2p12 Compton check 2∫J(Q)dQ = 0.9998645022987147
#
# ======================
# Sn_2p32
# ======================
#                 r             P             Q
# 432  2.000000e-08  1.554613e-12 -3.122479e-17
# 433  2.193213e-08  1.868545e-12 -4.116755e-17
# 434  2.405086e-08  2.246141e-12 -5.427154e-17
# 435  2.637428e-08  2.700290e-12 -7.154578e-17
# 436  2.892210e-08  3.246485e-12 -9.432000e-17
# 437  3.171605e-08  3.903364e-12 -1.243483e-16
# 438  3.477983e-08  4.693333e-12 -1.639426e-16
# 439  3.813958e-08  5.643344e-12 -2.161526e-16
#             r             P             Q
# 652  1.261569  6.026497e-08 -3.986801e-09
# 653  1.316133  2.417014e-08 -1.590744e-09
# 654  1.372396  9.413674e-09 -6.162200e-10
# 655  1.430384  3.558918e-09 -2.316458e-10
# 656  1.490124  1.305472e-09 -8.446094e-11
# 657  1.551641  4.644284e-10 -2.985496e-11
# 658  1.614960  1.601703e-10 -1.176727e-11
# 659  1.680107  5.352613e-11  4.993161e-13
# Sn_2p32 raw radial norm ∫(P²+Q²)dr = 1.000496505286198
# Sn_2p32 fine radial norm after interpolation = 1.0000000000000002
# Sn_2p32 momentum norm ∫I(p)dp = 0.9999992353333856
# Sn_2p32 Compton check 2∫J(Q)dQ = 0.9999469869285185
#
# ======================
# Sn_3s12
# ======================
#                  r         P             Q
# 1904  2.000000e-08  0.000003 -1.033606e-10
# 1905  2.193213e-08  0.000003 -1.242853e-10
# 1906  2.405086e-08  0.000004 -1.494480e-10
# 1907  2.637428e-08  0.000004 -1.797074e-10
# 1908  2.892210e-08  0.000004 -2.160951e-10
# 1909  3.171605e-08  0.000005 -2.598527e-10
# 1910  3.477983e-08  0.000005 -3.124718e-10
# 1911  3.813958e-08  0.000006 -3.757480e-10
#              r             P             Q
# 2146  2.892927  1.769931e-08 -5.263229e-10
# 2147  2.990510  8.216401e-09 -2.438724e-10
# 2148  3.090303  3.747239e-09 -1.110068e-10
# 2149  3.192327  1.678739e-09 -4.963047e-11
# 2150  3.296602  7.386423e-10 -2.179184e-11
# 2151  3.403145  3.191552e-10 -9.395522e-12
# 2152  3.511977  1.354016e-10 -4.203902e-12
# 2153  3.623115  5.639456e-11 -1.091682e-12
# Sn_3s12 raw radial norm ∫(P²+Q²)dr = 1.0002711944446232
# Sn_3s12 fine radial norm after interpolation = 1.0
# Sn_3s12 momentum norm ∫I(p)dp = 0.9999699081012429
# Sn_3s12 Compton check 2∫J(Q)dQ = 0.9996458047826925
#
# ======================
# Sn_3p12
# ======================
#                  r             P             Q
# 1400  2.000000e-08  1.765102e-11  4.997781e-07
# 1401  2.193213e-08  2.121539e-11  5.480675e-07
# 1402  2.405086e-08  2.550261e-11  6.010126e-07
# 1403  2.637428e-08  3.065899e-11  6.590732e-07
# 1404  2.892210e-08  3.686046e-11  7.227426e-07
# 1405  3.171605e-08  4.431864e-11  7.925616e-07
# 1406  3.477983e-08  5.328791e-11  8.691256e-07
# 1407  3.813958e-08  6.407429e-11  9.530778e-07
#              r             P             Q
# 1644  3.090303 -1.321650e-08  3.349676e-10
# 1645  3.192327 -6.262490e-09  1.588679e-10
# 1646  3.296602 -2.918307e-09  7.408857e-11
# 1647  3.403145 -1.337244e-09  3.396964e-11
# 1648  3.511977 -6.024598e-10  1.531081e-11
# 1649  3.623115 -2.668245e-10  6.782890e-12
# 1650  3.736579 -1.161572e-10  3.111689e-12
# 1651  3.852386 -4.969714e-11  8.723080e-13
# Sn_3p12 raw radial norm ∫(P²+Q²)dr = 1.0002786839853335
# Sn_3p12 fine radial norm after interpolation = 1.0000000000000002
# Sn_3p12 momentum norm ∫I(p)dp = 0.9999985705623444
# Sn_3p12 Compton check 2∫J(Q)dQ = 0.9999700658970115
#
# ======================
# Sn_3p32
# ======================
#                  r             P             Q
# 1652  2.000000e-08  7.190772e-13 -1.443657e-17
# 1653  2.193213e-08  8.642846e-13 -1.903354e-17
# 1654  2.405086e-08  1.038939e-12 -2.509208e-17
# 1655  2.637428e-08  1.249003e-12 -3.307871e-17
# 1656  2.892210e-08  1.501642e-12 -4.360822e-17
# 1657  3.171605e-08  1.805478e-12 -5.749161e-17
# 1658  3.477983e-08  2.170874e-12 -7.579775e-17
# 1659  3.813958e-08  2.610296e-12 -9.993673e-17
#              r             P             Q
# 1896  3.090303 -2.513139e-08  7.069254e-10
# 1897  3.192327 -1.217446e-08  3.414054e-10
# 1898  3.296602 -5.802938e-09  1.622338e-10
# 1899  3.403145 -2.721173e-09  7.584524e-11
# 1900  3.511977 -1.255217e-09  3.487972e-11
# 1901  3.623115 -5.694819e-10  1.577672e-11
# 1902  3.736579 -2.540882e-10  7.305298e-12
# 1903  3.852386 -1.114749e-10  2.364712e-12
# Sn_3p32 raw radial norm ∫(P²+Q²)dr = 1.000272392683343
# Sn_3p32 fine radial norm after interpolation = 0.9999999999999999
# Sn_3p32 momentum norm ∫I(p)dp = 0.9999996158582398
# Sn_3p32 Compton check 2∫J(Q)dQ = 0.9999879193654466
#
# ======================
# Sn_3d32
# ======================
#                 r             P             Q
# 886  2.000000e-08  7.349155e-19  3.451257e-14
# 887  2.193213e-08  9.666538e-19  4.150209e-14
# 888  2.405086e-08  1.272668e-18  4.990852e-14
# 889  2.637428e-08  1.676559e-18  6.001703e-14
# 890  2.892210e-08  2.209460e-18  7.217289e-14
# 891  3.171605e-08  2.912438e-18  8.679065e-14
# 892  3.477983e-08  3.839648e-18  1.043690e-13
# 893  3.813958e-08  5.062519e-18  1.255066e-13
#              r             P             Q
# 1134  3.511977  2.421823e-08 -4.751283e-10
# 1135  3.623115  1.247023e-08 -2.453158e-10
# 1136  3.736579  6.332507e-09 -1.248904e-10
# 1137  3.852386  3.171022e-09 -6.268716e-11
# 1138  3.970554  1.565666e-09 -3.101916e-11
# 1139  4.091100  7.621300e-10 -1.513003e-11
# 1140  4.214042  3.657157e-10 -7.507637e-12
# 1141  4.339397  1.729805e-10 -2.876914e-12
# Sn_3d32 raw radial norm ∫(P²+Q²)dr = 1.0002834570204173
# Sn_3d32 fine radial norm after interpolation = 1.0
# Sn_3d32 momentum norm ∫I(p)dp = 0.9999999421882986
# Sn_3d32 Compton check 2∫J(Q)dQ = 0.9999997944428571
#
# ======================
# Sn_3d52
# ======================
#                  r             P             Q
# 1142  2.000000e-08  3.460810e-20 -4.973530e-25
# 1143  2.193213e-08  4.552095e-20 -7.186586e-25
# 1144  2.405086e-08  5.993154e-20 -1.037770e-24
# 1145  2.637428e-08  7.895130e-20 -1.498656e-24
# 1146  2.892210e-08  1.040463e-19 -2.164784e-24
# 1147  3.171605e-08  1.371504e-19 -3.127892e-24
# 1148  3.477983e-08  1.808140e-19 -4.520549e-24
# 1149  3.813958e-08  2.384006e-19 -6.534474e-24
#              r             P             Q
# 1392  3.736579  7.706795e-09 -1.881983e-10
# 1393  3.852386  3.883670e-09 -9.445202e-11
# 1394  3.970554  1.929939e-09 -4.674973e-11
# 1395  4.091100  9.456538e-10 -2.281763e-11
# 1396  4.214042  4.568385e-10 -1.098088e-11
# 1397  4.339397  2.175656e-10 -5.209919e-12
# 1398  4.467181  1.021339e-10 -2.508654e-12
# 1399  4.597411  4.725610e-11 -9.481996e-13
# Sn_3d52 raw radial norm ∫(P²+Q²)dr = 1.0002812890568442
# Sn_3d52 fine radial norm after interpolation = 1.0000000000000002
# Sn_3d52 momentum norm ∫I(p)dp = 0.9999999427014874
# Sn_3d52 Compton check 2∫J(Q)dQ = 0.9999998483644911
#
# ======================
# Sn_4s12
# ======================
#                  r         P             Q
# 3374  2.000000e-08  0.000001 -4.672291e-11
# 3375  2.193213e-08  0.000002 -5.618165e-11
# 3376  2.405086e-08  0.000002 -6.755615e-11
# 3377  2.637428e-08  0.000002 -8.123457e-11
# 3378  2.892210e-08  0.000002 -9.768317e-11
# 3379  3.171605e-08  0.000002 -1.174633e-10
# 3380  3.477983e-08  0.000002 -1.412491e-10
# 3381  3.813958e-08  0.000003 -1.698523e-10
#              r             P             Q
# 3648  7.200320 -8.666440e-09  1.031041e-10
# 3649  7.377119 -4.984208e-09  5.924567e-11
# 3650  7.556632 -2.841726e-09  3.374999e-11
# 3651  7.738871 -1.606136e-09  1.905943e-11
# 3652  7.923848 -8.998714e-10  1.066961e-11
# 3653  8.111576 -4.997590e-10  5.920705e-12
# 3654  8.302065 -2.751104e-10  3.292488e-12
# 3655  8.495326 -1.501081e-10  1.690487e-12
# Sn_4s12 raw radial norm ∫(P²+Q²)dr = 1.0001424275947661
# Sn_4s12 fine radial norm after interpolation = 1.0000000000000002
# Sn_4s12 momentum norm ∫I(p)dp = 0.9999937849600357
# Sn_4s12 Compton check 2∫J(Q)dQ = 0.9999270331414631
#
# ======================
# Sn_4p12
# ======================
#                  r             P             Q
# 2792  2.000000e-08  7.656334e-12  2.167775e-07
# 2793  2.193213e-08  9.202421e-12  2.377229e-07
# 2794  2.405086e-08  1.106205e-11  2.606877e-07
# 2795  2.637428e-08  1.329869e-11  2.858714e-07
# 2796  2.892210e-08  1.598865e-11  3.134878e-07
# 2797  3.171605e-08  1.922372e-11  3.437716e-07
# 2798  3.477983e-08  2.311425e-11  3.769810e-07
# 2799  3.813958e-08  2.779296e-11  4.133951e-07
#               r             P             Q
# 3074   8.691372  3.185900e-09 -2.936073e-11
# 3075   8.890213  1.882516e-09 -1.736940e-11
# 3076   9.091859  1.103967e-09 -1.019750e-11
# 3077   9.296322  6.424990e-10 -5.941307e-12
# 3078   9.503612  3.710862e-10 -3.435083e-12
# 3079   9.713740  2.126920e-10 -1.970823e-12
# 3080   9.926715  1.209732e-10 -1.132557e-12
# 3081  10.142547  6.827741e-11 -6.090162e-13
# Sn_4p12 raw radial norm ∫(P²+Q²)dr = 1.0001376594804754
# Sn_4p12 fine radial norm after interpolation = 1.0000000000000002
# Sn_4p12 momentum norm ∫I(p)dp = 0.9999996867606424
# Sn_4p12 Compton check 2∫J(Q)dQ = 0.9999942091412648
#
# ======================
# Sn_4p32
# ======================
#                  r             P             Q
# 3082  2.000000e-08  3.106665e-13 -6.236534e-18
# 3083  2.193213e-08  3.734012e-13 -8.222404e-18
# 3084  2.405086e-08  4.488582e-13 -1.083967e-17
# 3085  2.637428e-08  5.396130e-13 -1.428986e-17
# 3086  2.892210e-08  6.487620e-13 -1.883855e-17
# 3087  3.171605e-08  7.800296e-13 -2.483612e-17
# 3088  3.477983e-08  9.378933e-13 -3.274429e-17
# 3089  3.813958e-08  1.127739e-12 -4.317222e-17
#               r             P             Q
# 3366   9.091859  2.830952e-09 -2.843558e-11
# 3367   9.296322  1.685011e-09 -1.689806e-11
# 3368   9.503612  9.956161e-10 -9.968898e-12
# 3369   9.713740  5.839667e-10 -5.838222e-12
# 3370   9.926715  3.400007e-10 -3.394101e-12
# 3371  10.142547  1.964969e-10 -1.958698e-12
# 3372  10.361247  1.127209e-10 -1.130798e-12
# 3373  10.582824  6.418228e-11 -6.172909e-13
# Sn_4p32 raw radial norm ∫(P²+Q²)dr = 1.0001336737969018
# Sn_4p32 fine radial norm after interpolation = 0.9999999999999999
# Sn_4p32 momentum norm ∫I(p)dp = 0.9999998785719002
# Sn_4p32 Compton check 2∫J(Q)dQ = 0.9999976054897042
#
# ======================
# Sn_4d32
# ======================
#                  r             P             Q
# 2154  2.000000e-08  2.826914e-19  1.327524e-14
# 2155  2.193213e-08  3.718315e-19  1.596375e-14
# 2156  2.405086e-08  4.895423e-19  1.919728e-14
# 2157  2.637428e-08  6.449026e-19  2.308552e-14
# 2158  2.892210e-08  8.498874e-19  2.776126e-14
# 2159  3.171605e-08  1.120293e-18  3.338397e-14
# 2160  3.477983e-08  1.476953e-18  4.014549e-14
# 2161  3.813958e-08  1.947340e-18  4.827603e-14
#               r             P             Q
# 2464  15.351441 -2.271969e-09  1.071202e-11
# 2465  15.632407 -1.522975e-09  7.196097e-12
# 2466  15.916425 -1.016333e-09  4.812278e-12
# 2467  16.203502 -6.751908e-10  3.203526e-12
# 2468  16.493647 -4.465398e-10  2.122882e-12
# 2469  16.786865 -2.939897e-10  1.400358e-12
# 2470  17.083163 -1.926804e-10  9.220959e-13
# 2471  17.382549 -1.257107e-10  5.951636e-13
# Sn_4d32 raw radial norm ∫(P²+Q²)dr = 1.000115705398518
# Sn_4d32 fine radial norm after interpolation = 0.9999999999999999
# Sn_4d32 momentum norm ∫I(p)dp = 0.9999999786621524
# Sn_4d32 Compton check 2∫J(Q)dQ = 0.9999999289303534
#
# ======================
# Sn_4d52
# ======================
#                  r             P             Q
# 2472  2.000000e-08  1.325846e-20 -1.903630e-25
# 2473  2.193213e-08  1.743920e-20 -2.750682e-25
# 2474  2.405086e-08  2.295994e-20 -3.972088e-25
# 2475  2.637428e-08  3.024646e-20 -5.736138e-25
# 2476  2.892210e-08  3.986042e-20 -8.285759e-25
# 2477  3.171605e-08  5.254270e-20 -1.197208e-24
# 2478  3.477983e-08  6.927032e-20 -1.730250e-24
# 2479  3.813958e-08  9.133191e-20 -2.501084e-24
#               r             P             Q
# 2784  15.916425 -1.556179e-09  8.992845e-12
# 2785  16.203502 -1.042225e-09  6.011783e-12
# 2786  16.493647 -6.949324e-10  4.001360e-12
# 2787  16.786865 -4.613158e-10  2.651581e-12
# 2788  17.083163 -3.048768e-10  1.749403e-12
# 2789  17.382549 -2.005931e-10  1.149099e-12
# 2790  17.685028 -1.313920e-10  7.531763e-13
# 2791  17.990608 -8.567991e-11  4.853091e-13
# Sn_4d52 raw radial norm ∫(P²+Q²)dr = 1.000114432495101
# Sn_4d52 fine radial norm after interpolation = 1.0000000000000002
# Sn_4d52 momentum norm ∫I(p)dp = 0.9999999822722418
# Sn_4d52 Compton check 2∫J(Q)dQ = 0.9999999418899784
#
# ======================
# Sn_5s12
# ======================
#                  r             P             Q
# 4040  2.000000e-08  4.480341e-07 -1.498778e-11
# 4041  2.193213e-08  4.913085e-07 -1.802196e-11
# 4042  2.405086e-08  5.387629e-07 -2.167067e-11
# 4043  2.637428e-08  5.908013e-07 -2.605843e-11
# 4044  2.892210e-08  6.478661e-07 -3.133482e-11
# 4045  3.171605e-08  7.104432e-07 -3.767988e-11
# 4046  3.477983e-08  7.790645e-07 -4.530990e-11
# 4047  3.813958e-08  8.543143e-07 -5.448525e-11
#               r             P             Q
# 4384  26.655322  1.338744e-09 -4.559456e-12
# 4385  27.043563  9.452240e-10 -3.219304e-12
# 4386  27.435053  6.652881e-10 -2.265938e-12
# 4387  27.829798  4.667893e-10 -1.589900e-12
# 4388  28.227801  3.264877e-10 -1.112053e-12
# 4389  28.629067  2.276387e-10 -7.753794e-13
# 4390  29.033601  1.582185e-10 -5.396447e-13
# 4391  29.441407  1.096224e-10 -3.718036e-13
# Sn_5s12 raw radial norm ∫(P²+Q²)dr = 1.0000525409927412
# Sn_5s12 fine radial norm after interpolation = 1.0
# Sn_5s12 momentum norm ∫I(p)dp = 0.9999995142443096
# Sn_5s12 Compton check 2∫J(Q)dQ = 0.9999927279624992
#
# ======================
# Sn_5p12
# ======================
#                  r             P             Q
# 3656  2.000000e-08  1.798325e-12  5.091663e-08
# 3657  2.193213e-08  2.161472e-12  5.583627e-08
# 3658  2.405086e-08  2.598262e-12  6.123024e-08
# 3659  2.637428e-08  3.123606e-12  6.714537e-08
# 3660  2.892210e-08  3.755426e-12  7.363190e-08
# 3661  3.171605e-08  4.515282e-12  8.074495e-08
# 3662  3.477983e-08  5.429091e-12  8.854517e-08
# 3663  3.813958e-08  6.528032e-12  9.709809e-08
#               r             P             Q
# 4032  40.711885 -1.023782e-09  2.137965e-12
# 4033  41.206159 -7.620837e-10  1.593523e-12
# 4034  41.703808 -5.660124e-10  1.185042e-12
# 4035  42.204833 -4.194466e-10  8.792789e-13
# 4036  42.709240 -3.101377e-10  6.509336e-13
# 4037  43.217031 -2.288015e-10  4.807990e-13
# 4038  43.728208 -1.684182e-10  3.545750e-13
# 4039  44.242776 -1.236929e-10  2.599901e-13
# Sn_5p12 raw radial norm ∫(P²+Q²)dr = 1.00003825849846
# Sn_5p12 fine radial norm after interpolation = 0.9999999999999999
# Sn_5p12 momentum norm ∫I(p)dp = 0.9999999895992937
# Sn_5p12 Compton check 2∫J(Q)dQ = 0.9999996825905746
#
# Total Pdcheck 2∫Jtotal dQ = 49.970739209571185
# Expected close to 50
#            Q  J_1s1/2(2)  J_2s1/2(2)  J_2p1/2(2)  J_2p3/2(4)  J_3s1/2(2)  \
# 0       0.00    0.016325    0.058660    0.029110    0.030390    0.137830
# 1       0.05    0.016325    0.058658    0.029110    0.030390    0.137799
# 2       0.10    0.016325    0.058652    0.029110    0.030390    0.137707
# 3       0.15    0.016325    0.058641    0.029110    0.030390    0.137553
# 4       0.20    0.016324    0.058627    0.029110    0.030390    0.137338
# ...      ...         ...         ...         ...         ...         ...
# 1996   99.80    0.000198    0.000031    0.000003    0.000002    0.000006
# 1997   99.85    0.000198    0.000031    0.000003    0.000002    0.000006
# 1998   99.90    0.000197    0.000031    0.000003    0.000002    0.000006
# 1999   99.95    0.000197    0.000031    0.000003    0.000002    0.000006
# 2000  100.00    0.000196    0.000031    0.000003    0.000002    0.000006
#
#         J_3p1/2(2)    J_3p3/2(4)    J_3d3/2(4)    J_3d5/2(6)  J_4s1/2(2)  \
# 0     8.162771e-02  8.418015e-02  5.629636e-02  5.688035e-02    0.318213
# 1     8.162770e-02  8.418015e-02  5.629636e-02  5.688035e-02    0.317811
# 2     8.162768e-02  8.418013e-02  5.629636e-02  5.688035e-02    0.316607
# 3     8.162761e-02  8.418004e-02  5.629636e-02  5.688035e-02    0.314611
# 4     8.162741e-02  8.417980e-02  5.629636e-02  5.688035e-02    0.311840
# ...            ...           ...           ...           ...         ...
# 1996  7.353574e-07  3.565559e-07  4.837702e-09  3.089290e-09    0.000001
# 1997  7.331035e-07  3.553159e-07  4.818154e-09  3.076218e-09    0.000001
# 1998  7.308579e-07  3.540809e-07  4.798686e-09  3.063202e-09    0.000001
# 1999  7.286205e-07  3.528509e-07  4.779298e-09  3.050240e-09    0.000001
# 2000  7.263912e-07  3.516259e-07  4.759987e-09  3.037330e-09    0.000001
#
#         J_4p1/2(2)    J_4p3/2(4)    J_4d3/2(4)    J_4d5/2(4)    J_5s1/2(2)  \
# 0     2.063470e-01  2.137170e-01  1.902752e-01  1.929252e-01  1.063238e+00
# 1     2.063468e-01  2.137167e-01  1.902752e-01  1.929252e-01  1.049979e+00
# 2     2.063446e-01  2.137141e-01  1.902751e-01  1.929252e-01  1.011311e+00
# 3     2.063362e-01  2.137040e-01  1.902749e-01  1.929249e-01  9.503902e-01
# 4     2.063144e-01  2.136780e-01  1.902740e-01  1.929239e-01  8.719455e-01
# ...            ...           ...           ...           ...           ...
# 1996  1.405041e-07  6.794298e-08  9.140565e-10  6.324189e-10  1.354998e-07
# 1997  1.400714e-07  6.770646e-08  9.100938e-10  6.297343e-10  1.352087e-07
# 1998  1.396380e-07  6.746932e-08  9.061741e-10  6.270832e-10  1.349187e-07
# 1999  1.392040e-07  6.723158e-08  9.023010e-10  6.244681e-10  1.346295e-07
# 2000  1.387695e-07  6.699328e-08  8.984770e-10  6.218909e-10  1.343409e-07
#
#         J_5p1/2(2)  J_total_Sn_relativistic
# 0     8.807502e-01                 9.382471
# 1     8.803715e-01                 9.354324
# 2     8.772222e-01                 9.268070
# 3     8.663648e-01                 9.120134
# 4     8.425244e-01                 8.909403
# ...            ...                      ...
# 1996  7.860293e-09                 0.000491
# 1997  7.836744e-09                 0.000490
# 1998  7.812946e-09                 0.000489
# 1999  7.788865e-09                 0.000488
# 2000  7.764479e-09                 0.000487
#
# [2001 rows x 18 columns]
