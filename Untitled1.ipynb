# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt

# CONFIGURATION
# Update these IDs based on your findings from Step 2
ID_PHOTO = 2012   # Example ID for photoelectric
ID_COMPT = 2013    # Example ID for compton
ID_PAIR  = 2014    # Example ID for pair production

files = {
    1e6: "1MeV_gamma.root",
    3e6: "3MeV_gamma.root",
    5e6: "5MeV_gamma.root",
    8e6: "8MeV_gamma.root",
    10e6: "10MeVgamma.root"
}

def calculate_mu(file_path, n_incident=500, thickness=1.0):
    with uproot.open(file_path) as f:
        tree = f["t"]
        pro_raw = tree["pro"].array(library="np")
        pro = np.concatenate(pro_raw).ravel()
        
        # Total interactions recorded
        n_interact = len(pro)
        n_trans = n_incident - n_interact
        
        # Total mu
        mu_tot = -np.log(n_trans / n_incident) / thickness
        
       # Component mus using count_nonzero to avoid ambiguity errors
        mu_p  = (np.count_nonzero(pro == ID_PHOTO) / n_interact) * mu_tot if n_interact > 0 else 0
        mu_c  = (np.count_nonzero(pro == ID_COMPT) / n_interact) * mu_tot if n_interact > 0 else 0
        mu_pp = (np.count_nonzero(pro == ID_PAIR) / n_interact) * mu_tot if n_interact > 0 else 0
        return mu_tot, mu_p, mu_c, mu_pp

# Data Collection
energies = sorted(files.keys())
results = {"tot": [], "p": [], "c": [], "pp": []}

for e in energies:
    mt, mp, mc, mpp = calculate_mu(files[e])
    results["tot"].append(mt)
    results["p"].append(mp)
    results["c"].append(mc)
    results["pp"].append(mpp)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(energies, results["tot"], 'b-', label='Total', lw=2)
plt.plot(energies, results["c"], 'r--', label='Compton')
plt.plot(energies, results["p"], 'g:', label='Photoelectric')
plt.plot(energies, results["pp"], 'cyan', linestyle='-.', label='Pair')

plt.xscale('log')
plt.yscale('log')
plt.xlabel('Incident Gamma Energy (eV)')
plt.ylabel('Absorption Coefficient (/cm)')
plt.grid(True, which="both", alpha=0.2)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 43
#      40 results = {"tot": [], "p": [], "c": [], "pp": []}
#      42 for e in energies:
# ---> 43     mt, mp, mc, mpp = calculate_mu(files[e])
#      44     results["tot"].append(mt)
#      45     results["p"].append(mp)
#
# Cell In[1], line 20, in calculate_mu(file_path, n_incident, thickness)
#      19 def calculate_mu(file_path, n_incident=500, thickness=1.0):
# ---> 20     with uproot.open(file_path) as f:
#      21         tree = f["t"]
#      22         pro_raw = tree["pro"].array(library="np")
#
# File /usr/local/lib/python3.14/site-packages/uproot/reading.py:143, in open(path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     134 if not isinstance(file_path, str) and not (
#     135     hasattr(file_path, "read") and hasattr(file_path, "seek")
#     136 ):
#     137     raise ValueError(
#     138         "'path' must be a string, pathlib.Path, an object with 'read' and "
#     139         "'seek' methods, or a length-1 dict of {file_path: object_path}, "
#     140         f"not {path!r}"
#     141     )
# --> 143 file = ReadOnlyFile(
#     144     file_path,
#     145     object_cache=object_cache,
#     146     array_cache=array_cache,
#     147     custom_classes=custom_classes,
#     148     decompression_executor=decompression_executor,
#     149     interpretation_executor=interpretation_executor,
#     150     **options,
#     151 )
#     153 if object_path is None:
#     154     return file.root_directory
#
# File /usr/local/lib/python3.14/site-packages/uproot/reading.py:574, in ReadOnlyFile.__init__(self, file_path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     566 if self._options["begin_chunk_size"] < _file_header_fields_big.size:
#     567     raise ValueError(
#     568         "begin_chunk_size={} is not enough to read the TFile header ({})".format(
#     569             self._options["begin_chunk_size"],
#     570             _file_header_fields_big.size,
#     571         )
#     572     )
# --> 574 self._begin_chunk = self._source.chunk(
#     575     0, self._options["begin_chunk_size"]
#     576 ).detach_memmap()
#     578 self.hook_before_interpret()
#     580 (
#     581     magic,
#     582     self._fVersion,
#    (...)
#     596     self._begin_chunk, _file_header_fields_small, {}
#     597 )
#
# File /usr/local/lib/python3.14/site-packages/uproot/source/fsspec.py:110, in FSSpecSource.chunk(self, start, stop)
#     108 self._num_requested_chunks += 1
#     109 self._num_requested_bytes += stop - start
# --> 110 data = self._fs.cat_file(self._file_path, start=start, end=stop)
#     111 future = uproot.source.futures.TrivialFuture(data)
#     112 return uproot.source.chunk.Chunk(self, start, stop, future)
#
# File /usr/local/lib/python3.14/site-packages/fsspec/spec.py:802, in AbstractFileSystem.cat_file(self, path, start, end, **kwargs)
#     790 """Get the content of a file
#     791
#     792 Parameters
#    (...)
#     799 kwargs: passed to ``open()``.
#     800 """
#     801 # explicitly set buffering off?
# --> 802 with self.open(path, "rb", **kwargs) as f:
#     803     if start is not None:
#     804         if start >= 0:
#
# File /usr/local/lib/python3.14/site-packages/fsspec/spec.py:1349, in AbstractFileSystem.open(self, path, mode, block_size, cache_options, compression, **kwargs)
#    1347 else:
#    1348     ac = kwargs.pop("autocommit", not self._intrans)
# -> 1349     f = self._open(
#    1350         path,
#    1351         mode=mode,
#    1352         block_size=block_size,
#    1353         autocommit=ac,
#    1354         cache_options=cache_options,
#    1355         **kwargs,
#    1356     )
#    1357     if compression is not None:
#    1358         from fsspec.compression import compr
#
# File /usr/local/lib/python3.14/site-packages/fsspec/implementations/local.py:214, in LocalFileSystem._open(self, path, mode, block_size, **kwargs)
#     212 if self.auto_mkdir and "w" in mode:
#     213     self.makedirs(self._parent(path), exist_ok=True)
# --> 214 return LocalFileOpener(path, mode, fs=self, **kwargs)
#
# File /usr/local/lib/python3.14/site-packages/fsspec/implementations/local.py:391, in LocalFileOpener.__init__(self, path, mode, autocommit, fs, compression, **kwargs)
#     389 self.compression = get_compression(path, compression)
#     390 self.blocksize = io.DEFAULT_BUFFER_SIZE
# --> 391 self._open()
#
# File /usr/local/lib/python3.14/site-packages/fsspec/implementations/local.py:396, in LocalFileOpener._open(self)
#     394 if self.f is None or self.f.closed:
#     395     if self.autocommit or "w" not in self.mode:
# --> 396         self.f = open(self.path, mode=self.mode)
#     397         if self.compression:
#     398             compress = compr[self.compression]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/root/geant4/1MeV_gamma.root'
