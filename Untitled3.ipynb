# %%
import ROOT
# %jsroot on

f = ROOT.TFile.Open("tumor.root")
t = f.Get("t")

print("Tree entries =", t.GetEntries())
print("vlm min =", t.GetMinimum("vlm"))
print("vlm max =", t.GetMaximum("vlm"))

c = ROOT.TCanvas("c", "et for different volumes", 1000, 700)
legend = ROOT.TLegend(0.72, 0.68, 0.90, 0.90)
legend.SetBorderSize(1)
legend.SetFillStyle(0)

colors = [ROOT.kRed, ROOT.kBlue, ROOT.kGreen+2, ROOT.kMagenta, ROOT.kCyan+2, ROOT.kOrange+7]

hist_list = []
first = True

for i, vlm in enumerate([1,2,3]):   # change these if needed
    hname = f"h_vlm_{vlm}"
    h = ROOT.TH1F(hname, "et for different volumes;et;Counts", 100, 0, 700)

    t.Draw(f"et>>{hname}", f"vlm=={vlm}", "goff")
    print("vlm =", vlm, "entries =", h.GetEntries())

    if h.GetEntries() == 0:
        continue

    h.SetLineColor(colors[i % len(colors)])
    h.SetLineWidth(2)

    if first:
        h.Draw("hist")
        first = False
    else:
        h.Draw("hist same")

    legend.AddEntry(h, f"vlm = {vlm}", "l")
    hist_list.append(h)

legend.Draw()
c.Update()
c.Draw()
# Out:
# Error in <TFile::TFile>: file /root/geant4/tumor.root does not exist
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 4
#       1 import ROOT
#       2 get_ipython().run_line_magic('jsroot', 'on')
# ----> 4 f = ROOT.TFile.Open("tumor.root")
#       5 t = f.Get("t")
#       7 print("Tree entries =", t.GetEntries())
#
# File /usr/lib64/python3.14/site-packages/ROOT/_pythonization/_tfile.py:95, in _TFileOpen(klass, *args)
#      92 f = klass._OriginalOpen(*args)
#      93 if not f:
#      94     # args[0] can be either a string or a TFileOpenHandle
# ---> 95     raise OSError('Failed to open file {}'.format(str(args[0])))
#      96 return f
#
# OSError: Failed to open file tumor.root
